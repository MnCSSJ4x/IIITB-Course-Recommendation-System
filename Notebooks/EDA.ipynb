# %% [markdown]
# ## Exploratory Data Analysis(EDA) of the given dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn.preprocessing as preprocessing

# %%
df=pd.read_excel('Course Recommendation System.xlsx')
df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1)
df.head()
# Out:
#    Data Structures and Algorithms  Computer Architecture\n  \
# 0                            0.30                     0.85
# 1                            0.70                     0.80
# 2                            0.70                     0.00
# 3                            0.65                     0.70
# 4                            0.70                     0.60
#
#    Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                    0.85       0.90           0.70                0.70
# 1                    0.20       0.80           0.80                0.50
# 2                    1.00       1.00           1.00                1.00
# 3                    0.20       0.75           0.75                0.75
# 4                    0.20       0.00           0.80                0.50
#
#    Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                0.80                   NaN
# ...

# %%
df['mean'] = df.mean(axis=1,skipna=True,numeric_only=True)
df.head()
# Out:
#    Data Structures and Algorithms  Computer Architecture\n  \
# 0                            0.30                     0.85
# 1                            0.70                     0.80
# 2                            0.70                     0.00
# 3                            0.65                     0.70
# 4                            0.70                     0.60
#
#    Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                    0.85       0.90           0.70                0.70
# 1                    0.20       0.80           0.80                0.50
# 2                    1.00       1.00           1.00                1.00
# 3                    0.20       0.75           0.75                0.75
# 4                    0.20       0.00           0.80                0.50
#
#    Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                0.80                   NaN
# ...

# %%
df.shape
# Out:
# (162, 26)

# %%
# sns.set(rc={'figure.figsize':(65,8)})
# sns.barplot(y=df['mean'],x=[i for i in range(0,df.shape[0])])
# df.drop(axis="columns",labels=["mean"],inplace=True)
# df

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data (150 users with random mean values)
mean_values = df['mean'].to_numpy()

# Calculate the overall mean of all the users
overall_mean = np.mean(mean_values)

fig = plt.figure(figsize=(8, 6))
# Plot the histogram with the mean values on the x-axis
plt.hist(mean_values, bins=15, alpha=0.65)

# Add a vertical line at the overall mean value
plt.axvline(x=overall_mean, color='red')

# Add labels and a title
plt.xlabel('Mean Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mean Values for 162 Users')

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['Data Structures and Algorithms', 'Computer Architecture\n',
#        'Discrete Mathematics\n', 'Economics', 'Programming-2',
#        'Machine Learning\n', 'Mathematics For Machine Learning\n',
#        'Visual Recognition\n', 'Natural Language Processing\n',
#        'Reinforcement Learning', 'Software Production Engineering\n',
#        'Computer Graphics\n', 'Data Visualization\n',
#        'Programming Languages\n', 'Cloud Computing\n',
#        'Digital CMOS VLSI Design ', 'System design with FPGA ', 'ASIC design ',
#        'VLSI Architecture Design\n',
#        'High level synthesis and optimization of Digital Circuits ',
#        'Digital Sociology ', 'Privacy in the Digital Age',
#        'Technology Ethics and AI ', 'Techno-economics of networks ',
#        'The Web and the Mind ', 'mean'],
#       dtype='object')

# %%
df_core = df[['Data Structures and Algorithms', 'Computer Architecture\n',
       'Discrete Mathematics\n', 'Economics', 'Programming-2']]
df_ai = df[['Machine Learning\n', 'Mathematics For Machine Learning\n',
       'Visual Recognition\n', 'Natural Language Processing\n',
       'Reinforcement Learning']]
df_tscd = df[['Software Production Engineering\n',
       'Computer Graphics\n', 'Data Visualization\n',
       'Programming Languages\n', 'Cloud Computing\n']]
df_vlsi = df[['Digital CMOS VLSI Design ', 'System design with FPGA ', 'ASIC design ',
       'VLSI Architecture Design\n',
       'High level synthesis and optimization of Digital Circuits ']]
df_dt = df[['Digital Sociology ', 'Privacy in the Digital Age',
       'Technology Ethics and AI ', 'Techno-economics of networks ',
       'The Web and the Mind ']]

# %%
mean_core = df_core.mean(skipna=True,numeric_only=True)
mean_ai = df_ai.mean(skipna=True,numeric_only=True)
mean_tscd = df_tscd.mean(skipna=True,numeric_only=True)
mean_vlsi = df_vlsi.mean(skipna=True,numeric_only=True)
mean_dt = df_dt.mean(skipna=True,numeric_only=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a sample Pandas Series
# Create a bar graph using Matplotlib
fig = plt.figure(figsize=(8, 6))
mean_dt.plot.bar()

# Add labels and a title
plt.xlabel('Subjects')
plt.ylabel('Mean')
plt.title('Average Rating for DigiSoc Subjects')
plt.xticks(rotation=15)
# Show the plot
plt.show()

# %%
mean_dt
# Out:
# Digital Sociology                0.318243
# Privacy in the Digital Age       0.452708
# Technology Ethics and AI         0.423286
# Techno-economics of networks     0.396622
# The Web and the Mind             0.510897
# dtype: float64

# %%
count_core = df_core.count(numeric_only=True)
count_ai = df_ai.count(numeric_only=True)
count_tscd = df_tscd.count(numeric_only=True)
count_vlsi = df_vlsi.count(numeric_only=True)
count_dt = df_dt.count(numeric_only=True)

# %%
count_dt
# Out:
# Digital Sociology                 74
# Privacy in the Digital Age       104
# Technology Ethics and AI          70
# Techno-economics of networks      74
# The Web and the Mind              78
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a sample Pandas Series
# Create a bar graph using Matplotlib
fig = plt.figure(figsize=(8, 6))
count_vlsi.plot.bar()

# Add labels and a title
plt.ylim(0,162)
plt.xlabel('Subjects')
plt.ylabel('Count')
plt.title('Number of entries for VLSI Subjects')
plt.xticks(rotation=15)
# Show the plot
plt.show()
