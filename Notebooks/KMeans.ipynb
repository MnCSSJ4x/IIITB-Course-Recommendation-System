# %% [markdown]
# ## Course Reccomendation System

# %%
from __future__ import annotations # To prevent Subscript for class "list" will generate runtime exception; enclose type annotation in quotes
import seaborn as sns
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import random
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import scipy
from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline

# %% [markdown]
# ### KMeans algorithm

# %%
def eucledian_distance(x1,x2) :
  return np.sqrt(np.sum((x1-x2)**2)) #vector based

def minkowski_distance(x1,x2,p):
  from scipy.spatial import distance
  return distance.minkowski(x1,x2,p)

class Kmeans:
  #K = number of clusters
  #iter = number of iterations
  def __init__(self,K,iter,p):
    self.K=K
    self.iter=iter
    self.p=p
    #Initialising empty K clusters -> storing indicies
    self.clusters = [[] for _ in range(self.K)] 
    #storing centroids 
    self.centroids=[]
    self.inertia = 0.0 

  def plus_plus(self,ds:np.array, k, random_state=1000):
    """
    Create cluster centroids using the k-means++ algorithm.
    Parameters
    ----------
    ds : numpy array
        The dataset to be used for centroid initialization.
    k : int
        The desired number of clusters for which centroids are required.
    Returns
    -------
    centroids : numpy array
        Collection of k centroids as a numpy array.
    Inspiration from here: https://stackoverflow.com/questions/5466323/how-could-one-implement-the-k-means-algorithm
    """

    np.random.seed(random_state)
    centroids = [ds[0]]

    for _ in range(1, k):
        dist_sq = np.array([min([np.inner(c-x,c-x) for c in centroids]) for x in ds])
        probs = dist_sq/dist_sq.sum()
        cumulative_probs = probs.cumsum()
        r = np.random.rand()
        
        for j, p in enumerate(cumulative_probs):
            if r < p:
                i = j
                break
        
        centroids.append(ds[i])

    return np.array(centroids)

  def predict(self,X,choice=0): #no fit required for unsupervised learning models
    self.X=X
    self.n_samples,self.n_features = X.shape #numpy N-d array
    
    #initialise centroids
    if choice == 0:
        centroids = np.zeros((self.K, self.n_features)) # row , column full with zero 
        for k in range(self.K): # iterations of 
            centroid = X[np.random.choice(range(self.n_samples))] # random centroids
            centroids[k] = centroid
        self.centroids = centroids
    elif choice == 1:
      self.centroids=self.plus_plus(X,self.K)

    elif choice == 2:
      self.centroids=self.naive_sharding(X,self.K)
    

    #optimise 
    for _ in range(self.iter):
      #update clusters
      self.clusters=self._create_clusters(self.centroids)
      #update centroids 
      centroids_old = self.centroids #for convergence test 
      self.centroids = self._get_centroids(self.clusters)
       #get cetnroids assign mean value of cluster to the centroid
      #check for convergence
      if self._isConverged(centroids_old,self.centroids):
        break

      #break 
    #classify the samples based on index of cluster
    labels = self.getClusterLabels(self.clusters)
    self.calculateInertia(X,labels)
    return labels
    #return cluster labels 
  def _create_clusters(self,centroids):
    clusters = [[] for _ in range(self.K)]
    for idx,sample in enumerate(self.X):
      #find the closest centroid to classify, then put it in the specific cluster
      #here cluster is an list of list 
      centroid_idx = self._closest_centroid(sample,centroids)
      clusters[centroid_idx].append(idx)
    return clusters
  def function (self,point):
    return minkowski_distance(self.sample, point, self.p)

  def _closest_centroid(self,sample,centroids):
    #distance metric  
    distances = [minkowski_distance(sample,point,self.p) for point in centroids]
    #argmin for required parameters
    closest_idx = np.argmin(distances)
    # self.sample=sample
    # closest_idx = scipy.optimize.minimize (fun=function ,x0=np.asarray(centroids))
    return closest_idx
  def _get_centroids(self,clusters):
    centroids = np.zeros((self.K,self.n_features)) #Dimension = N as N = number of features
    for cluster_idx, cluster in enumerate(clusters):
      #calling mean on a specific current cluster as X is array of various clusters
      if(len(cluster)!=0):
        cluster_mean = np.mean(self.X[cluster],axis = 0)
        centroids[cluster_idx] = cluster_mean #set mean as newer centroids
    return centroids 
  def _isConverged(self,centroids_old,centroids):
    distances = [minkowski_distance(centroids_old[i],centroids[i],self.p) for i in range(self.K)]
    return sum(distances)==0 #no more change occured in 2 iteration so converges 

  def getClusterLabels(self,clusters):
    labels = np.empty(self.n_samples)
    for cluster_idx,cluster in enumerate(clusters):
      for sample_idx in cluster:
        labels[sample_idx] = cluster_idx
    return labels 
  
  def calculateInertia(self,datapoints: list[int],labels: list[any])->None:
    labels = labels.astype(int)
    for idx,pts in enumerate(datapoints):
      self.inertia += minkowski_distance(self.centroids[labels[idx]],pts,2)**2
  def predictPoint(self,datapoint):
    return self._closest_centroid(datapoint,self.centroids)

# %% [markdown]
# ### Testing on generated datapoints

# %%
df=pd.read_excel('../Course Recommendation System.xlsx')
df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1).fillna(0.5)
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                      0.85       0.90           0.70                0.70
# 1                      0.20       0.80           0.80                0.50
# 2                      1.00       1.00           1.00                1.00
# 3                      0.20       0.75           0.75                0.75
# 4                      0.20       0.00           0.80                0.50
# ..                      ...        ...            ...                 ...
# 157                    0.50       0.70           0.60                0.50
# 158                    0.00       0.70           0.70                0.00
# 159                    0.40       0.90           0.80                0.70
# 160                    0.20       0.40           0.70                0.70
# 161                    0.90       0.40           0.40                0.70
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                  0.80                  0.50
# 1                                  0.10                  0.20
# 2                                  1.00                  0.80
# 3                                  0.75                  0.75
# 4                                  0.60                  0.40
# ..                                  ...                   ...
# 157                                0.30                  0.70
# 158                                0.00                  0.00
# 159                                0.40                  0.50
# 160                                0.80                  0.50
# 161                                0.90                  0.50
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                              0.5                     0.5  ...
# 1                              0.5                     0.5  ...
# 2                              0.9                     1.0  ...
# 3                              0.5                     0.5  ...
# 4                              0.4                     0.2  ...
# ..                             ...                     ...  ...
# 157                            0.5                     0.5  ...
# 158                            0.5                     0.5  ...
# 159                            0.4                     0.2  ...
# 160                            0.5                     0.7  ...
# 161                            0.5                     0.8  ...
#
#      Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                          0.5                       0.5           0.5
# 1                          0.5                       0.5           0.5
# 2                          0.5                       0.5           0.5
# 3                          0.5                       0.5           0.5
# 4                          0.0                       0.0           0.0
# ..                         ...                       ...           ...
# 157                        0.5                       0.5           0.5
# 158                        0.5                       0.5           0.5
# 159                        0.5                       0.5           0.5
# 160                        0.5                       0.5           0.5
# 161                        0.5                       0.5           0.5
#
#      VLSI Architecture Design\n  \
# 0                           0.5
# 1                           0.5
# 2                           0.5
# 3                           0.5
# 4                           0.0
# ..                          ...
# 157                         0.5
# 158                         0.5
# 159                         0.5
# 160                         0.5
# 161                         0.5
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                                  0.5
# 1                                                  0.5
# 2                                                  0.5
# 3                                                  0.5
# 4                                                  0.0
# ..                                                 ...
# 157                                                0.5
# 158                                                0.5
# 159                                                0.5
# 160                                                0.5
# 161                                                0.5
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0                   0.5                         0.6
# 1                   0.5                         0.5
# 2                   0.5                         0.4
# 3                   0.8                         0.5
# 4                   0.0                         0.0
# ..                  ...                         ...
# 157                 0.5                         0.0
# 158                 0.5                         0.5
# 159                 0.5                         1.0
# 160                 0.5                         0.5
# 161                 0.5                         0.5
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                          0.5                            0.5
# 1                          0.5                            0.5
# 2                          0.5                            0.5
# 3                          0.5                            0.8
# 4                          0.0                            0.0
# ..                         ...                            ...
# 157                        0.5                            0.5
# 158                        0.5                            0.5
# 159                        0.5                            0.5
# 160                        0.5                            0.5
# 161                        0.5                            0.5
#
#      The Web and the Mind
# 0                      0.5
# 1                      0.5
# 2                      0.5
# 3                      0.5
# 4                      0.0
# ..                     ...
# 157                    0.5
# 158                    0.2
# 159                    1.0
# 160                    0.5
# 161                    0.5
#
# [162 rows x 25 columns]

# %%
df=df[[df.columns[0],df.columns[1],df.columns[2],df.columns[3],df.columns[4]]]
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2
# 0                      0.85       0.90           0.70
# 1                      0.20       0.80           0.80
# 2                      1.00       1.00           1.00
# 3                      0.20       0.75           0.75
# 4                      0.20       0.00           0.80
# ..                      ...        ...            ...
# 157                    0.50       0.70           0.60
# 158                    0.00       0.70           0.70
# 159                    0.40       0.90           0.80
# 160                    0.20       0.40           0.70
# 161                    0.90       0.40           0.40
#
# [162 rows x 5 columns]

# %% [markdown]
# #### Trial Run

# %%
k=Kmeans(K=29,iter=150,p=2)
y_pred=k.predict(np.array(df),choice=0)
k.centroids=np.array(k.centroids, dtype='int')
len(k.centroids)
y_pred
# Out:
# array([ 9., 10., 16., 10., 11., 10., 17.,  5.,  3.,  4., 13., 10., 28.,
#        28.,  3., 10., 10.,  9.,  3., 13., 10.,  3., 25., 22.,  7., 22.,
#         1., 10., 23., 12., 11., 10., 12.,  9., 10., 11.,  3.,  3., 17.,
#        28., 26.,  9., 25., 10., 26., 15., 22., 12., 21., 26.,  8.,  2.,
#        17.,  7., 28.,  8., 23.,  3., 13., 16., 26., 26., 15., 16.,  5.,
#        13., 17., 25.,  3.,  2.,  9., 26., 10., 17.,  8.,  8.,  3., 13.,
#         8., 22., 23.,  3.,  4., 17., 12., 13., 21.,  3., 21., 12., 17.,
#        23.,  7.,  5.,  5.,  8., 15., 22.,  5., 26., 20.,  2., 25., 10.,
#        23., 17., 10., 16., 23.,  8., 17.,  1.,  3., 15.,  1., 23.,  3.,
#         9., 23., 15., 12., 15., 19., 17., 15., 16., 17.,  4.,  3., 15.,
#        13.,  3.,  0.,  7., 23.,  2.,  2., 15., 15., 15., 17., 28., 12.,
#        16., 28., 16., 28., 22.,  3., 15., 15.,  0.,  6., 10., 25.,  4.,
#        16.,  9., 25., 26.,  5.,  4.])

# %% [markdown]
# #### Elbow plot: Our implementation

# %%
distortions = []
K = range(1,20,1)
for k in K:
    kmeanModel = Kmeans(K=k,iter=150,p=2)
    kmeanModel.predict(np.array(df),choice=1)
    distortions.append(kmeanModel.inertia)

# %%
plt.plot(K,distortions)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %% [markdown]
# ### SKlearn Comparision

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
core_courses = ['Data Structures and Algorithms','Computer Architecture\n','Discrete Mathematics\n','Economics','Programming-2']
wcss = []  #Within Cluster Sum of Squares
for number_of_clusters in range(1, 10): 
    kmeans = KMeans(n_clusters = number_of_clusters, random_state = 42,init='random')
    kmeans.fit(df) 
    wcss.append(kmeans.inertia_)
    # print(kmeans.n_iter_)
ks = [x for x in range(1,10)]
plt.plot(ks, wcss)

# %%
distortions
# Out:
# [82.11226015529861,
#  64.34069735843698,
#  53.40007705800851,
#  44.89006011022395,
#  40.46880616557636,
#  38.7225800340446,
#  36.90427502199772,
#  33.229013950847936,
#  29.7468977651558,
#  27.402572353389942,
#  25.39197318953163,
#  22.77146446374487,
#  23.20119881565865,
#  22.48051671018362,
#  20.95421024376671,
#  19.873396675111746,
#  17.499632477179862,
#  16.55787799278744,
#  15.502885248575128]

# %%
wcss
# Out:
# [82.11226015529861,
#  63.24078648485308,
#  51.58991760241395,
#  44.89950583242211,
#  40.815556917228335,
#  36.262752708925674,
#  33.48422395110803,
#  30.679086316240635,
#  27.97433851426379]

# %% [markdown]
# # Working on actual data

# %% [markdown]
# #### Applying Pre-processing steps on data:

# %%
df=pd.read_excel('../Course Recommendation System.xlsx')
df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1) 
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/d3/cp13q0jn14z64vh0k61msh680000gn/T/ipykernel_94447/899673285.py in <module>
# ----> 1 df=pd.read_excel('Course Recommendation System.xlsx')
#       2 df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1)
#       3 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# --> 457         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458     elif engine and engine != io.engine:
#     459         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1374                 ext = "xls"
#    1375             else:
# -> 1376                 ext = inspect_excel_format(
#    1377                     content_or_path=path_or_buffer, storage_options=storage_options
#    1378                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1248         content_or_path = BytesIO(content_or_path)
#    1249
# -> 1250     with get_handle(
#    1251         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252     ) as handle:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Course Recommendation System.xlsx'

# %%
df_cluster=df[[df.columns[0],df.columns[1],df.columns[2],df.columns[3],df.columns[4]]]
df_cluster
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2
# 0                      0.85       0.90           0.70
# 1                      0.20       0.80           0.80
# 2                      1.00       1.00           1.00
# 3                      0.20       0.75           0.75
# 4                      0.20       0.00           0.80
# ..                      ...        ...            ...
# 157                    0.50       0.70           0.60
# 158                    0.00       0.70           0.70
# 159                    0.40       0.90           0.80
# 160                    0.20       0.40           0.70
# 161                    0.90       0.40           0.40
#
# [162 rows x 5 columns]

# %%
num_cluster = 4

# %%
k=Kmeans(K=num_cluster,iter=150,p=2)
y_pred=k.predict(np.array(df_cluster),choice=0)
k.centroids=np.array(k.centroids, dtype='int')
len(k.centroids)
y_pred
# Out:
# array([3., 1., 3., 1., 1., 3., 2., 1., 3., 2., 3., 3., 2., 3., 3., 1., 3.,
#        3., 3., 3., 1., 3., 1., 3., 3., 3., 1., 1., 2., 1., 1., 3., 2., 3.,
#        3., 1., 0., 3., 2., 2., 1., 3., 1., 3., 1., 3., 3., 2., 1., 1., 1.,
#        3., 2., 3., 3., 1., 2., 3., 3., 1., 1., 1., 3., 3., 1., 3., 2., 1.,
#        3., 3., 3., 1., 3., 2., 1., 1., 3., 3., 1., 0., 2., 3., 0., 2., 1.,
#        3., 0., 3., 0., 1., 2., 2., 3., 1., 2., 0., 3., 3., 1., 1., 0., 2.,
#        1., 3., 2., 2., 0., 3., 2., 0., 2., 1., 0., 3., 1., 2., 3., 3., 2.,
#        3., 1., 3., 0., 2., 3., 3., 2., 0., 3., 3., 3., 3., 1., 3., 2., 2.,
#        2., 3., 3., 3., 2., 3., 1., 3., 3., 3., 2., 3., 3., 3., 3., 1., 1.,
#        3., 1., 0., 3., 0., 1., 1., 1., 0.])

# %%
df = pd.concat([df,pd.DataFrame(y_pred,columns=["label"],dtype='int')],axis="columns")

# %%
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                      0.85       0.90           0.70                0.70
# 1                      0.20       0.80           0.80                0.50
# 2                      1.00       1.00           1.00                1.00
# 3                      0.20       0.75           0.75                0.75
# 4                      0.20       0.00           0.80                0.50
# ..                      ...        ...            ...                 ...
# 157                    0.50       0.70           0.60                0.50
# 158                    0.00       0.70           0.70                0.00
# 159                    0.40       0.90           0.80                0.70
# 160                    0.20       0.40           0.70                0.70
# 161                    0.90       0.40           0.40                0.70
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                  0.80                   NaN
# 1                                  0.10                  0.20
# 2                                  1.00                  0.80
# 3                                  0.75                  0.75
# 4                                  0.60                  0.40
# ..                                  ...                   ...
# 157                                0.30                  0.70
# 158                                0.00                  0.00
# 159                                0.40                  0.50
# 160                                0.80                   NaN
# 161                                0.90                   NaN
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                              NaN                     NaN  ...
# 1                              NaN                     NaN  ...
# 2                              0.9                     1.0  ...
# 3                              NaN                     NaN  ...
# 4                              0.4                     0.2  ...
# ..                             ...                     ...  ...
# 157                            NaN                     NaN  ...
# 158                            NaN                     NaN  ...
# 159                            0.4                     0.2  ...
# 160                            NaN                     0.7  ...
# 161                            NaN                     0.8  ...
#
#      System design with FPGA   ASIC design   VLSI Architecture Design\n  \
# 0                         NaN           NaN                         NaN
# 1                         NaN           NaN                         NaN
# 2                         NaN           NaN                         NaN
# 3                         NaN           NaN                         NaN
# 4                         0.0           0.0                         0.0
# ..                        ...           ...                         ...
# 157                       NaN           NaN                         NaN
# 158                       NaN           NaN                         NaN
# 159                       NaN           NaN                         NaN
# 160                       NaN           NaN                         NaN
# 161                       NaN           NaN                         NaN
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  0.0
# ..                                                 ...
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0                   NaN                         0.6
# 1                   NaN                         0.5
# 2                   NaN                         0.4
# 3                   0.8                         NaN
# 4                   0.0                         0.0
# ..                  ...                         ...
# 157                 NaN                         0.0
# 158                 NaN                         NaN
# 159                 NaN                         1.0
# 160                 NaN                         NaN
# 161                 NaN                         NaN
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            0.8
# 4                          0.0                            0.0
# ..                         ...                            ...
# 157                        NaN                            NaN
# 158                        NaN                            NaN
# 159                        NaN                            NaN
# 160                        NaN                            NaN
# 161                        NaN                            NaN
#
#      The Web and the Mind   label
# 0                      NaN      3
# 1                      NaN      1
# 2                      NaN      3
# 3                      NaN      1
# 4                      0.0      1
# ..                     ...    ...
# 157                    NaN      0
# 158                    0.2      1
# 159                    1.0      1
# 160                    NaN      1
# 161                    NaN      0
#
# [162 rows x 26 columns]

# %%
df_cluster_rep = df.groupby(['label'], as_index=False).mean()

# %%
df_cluster_rep.drop(labels="label",axis="columns",inplace=True)

# %%
df_cluster_rep
# Out:
#    Data Structures and Algorithms  Computer Architecture\n  \
# 0                        0.662000                 0.925333
# 1                        0.750000                 0.467778
# 2                        0.864516                 0.614516
# 3                        0.845301                 0.787465
#
#    Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                0.536000   0.730667       0.310000            0.729167
# 1                0.153333   0.564444       0.851111            0.776190
# 2                0.825484   0.091935       0.917742            0.907143
# 3                0.805385   0.808909       0.906308            0.796763
#
#    Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                            0.733333              0.590000
# 1                            0.574419              0.526829
# 2                            0.812500              0.629630
# 3                            0.783649              0.695933
#
#    Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                       0.787500                0.688889  ...
# 1                       0.435862                0.523000  ...
# 2                       0.677273                0.700000  ...
# 3                       0.571245                0.590610  ...
#
#    Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                   0.227500                  0.315000      0.130000
# 1                   0.216000                  0.196000      0.204000
# 2                   0.268421                  0.205263      0.168421
# 3                   0.280769                  0.308333      0.288000
#
#    VLSI Architecture Design\n  \
# 0                    0.318750
# 1                    0.180000
# 2                    0.227778
# 3                    0.268000
#
#    High level synthesis and optimization of Digital Circuits   \
# 0                                           0.100000
# 1                                           0.082609
# 2                                           0.122222
# 3                                           0.296000
#
#    Digital Sociology   Privacy in the Digital Age  Technology Ethics and AI   \
# 0            0.166667                    0.440000                   0.350000
# 1            0.328000                    0.425862                   0.386957
# 2            0.091176                    0.381818                   0.300000
# 3            0.492308                    0.510039                   0.563750
#
#    Techno-economics of networks   The Web and the Mind
# 0                       0.414286               0.414286
# 1                       0.343478               0.493333
# 2                       0.088235               0.578125
# 3                       0.631481               0.516000
#
# [4 rows x 25 columns]

# %%
print((df_cluster_rep == 0).any().any())
# Out:
# False

# %%
matrix = df_cluster_rep.to_numpy()
matrix
# Out:
# array([[0.662     , 0.92533333, 0.536     , 0.73066667, 0.31      ,
#         0.72916667, 0.73333333, 0.59      , 0.7875    , 0.68888889,
#         0.76      , 0.33      , 0.6125    , 0.28888889, 0.5       ,
#         0.2275    , 0.315     , 0.13      , 0.31875   , 0.1       ,
#         0.16666667, 0.44      , 0.35      , 0.41428571, 0.41428571],
#        [0.75      , 0.46777778, 0.15333333, 0.56444444, 0.85111111,
#         0.77619048, 0.5744186 , 0.52682927, 0.43586207, 0.523     ,
#         0.71363636, 0.44147059, 0.48225806, 0.52894737, 0.525     ,
#         0.216     , 0.196     , 0.204     , 0.18      , 0.0826087 ,
#         0.328     , 0.42586207, 0.38695652, 0.34347826, 0.49333333],
#        [0.86451613, 0.61451613, 0.82548387, 0.09193548, 0.91774194,
#         0.90714286, 0.8125    , 0.62962963, 0.67727273, 0.7       ,
#         0.6173913 , 0.37083333, 0.54090909, 0.57083333, 0.55454545,
#         0.26842105, 0.20526316, 0.16842105, 0.22777778, 0.12222222,
#         0.09117647, 0.38181818, 0.3       , 0.08823529, 0.578125  ],
#        [0.84530096, 0.78746479, 0.80538526, 0.80890885, 0.90630814,
#         0.79676316, 0.78364891, 0.69593299, 0.57124458, 0.59060954,
#         0.6575    , 0.54699675, 0.69743639, 0.5952381 , 0.63368015,
#         0.28076923, 0.30833333, 0.288     , 0.268     , 0.296     ,
#         0.49230769, 0.51003867, 0.56375   , 0.63148148, 0.516     ]])

# %%
matrix.shape
# Out:
# (4, 25)

# %% [markdown]
# Packaging the above into a function

# %%
def cluster_to_matrix(X_train,y_train,num_cluster):
    k=Kmeans(K=num_cluster,iter=150,p=2)
    y_pred=k.predict(np.array(X_train),choice=0)
    k.centroids=np.array(k.centroids, dtype='int')
    X_train2 = pd.concat([X_train,y_train,pd.DataFrame(y_pred,columns=["label"],dtype='int')],axis="columns")
    df_cluster_rep = X_train2.groupby(['label'], as_index=False).mean()
    df_cluster_rep.drop(labels="label",axis="columns",inplace=True)
    matrix = df_cluster_rep.to_numpy()
    return matrix,k

# %% [markdown]
# Performing the task on dataset

# %%
df=pd.read_excel('Course Recommendation System.xlsx')
df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1) 
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                      0.85       0.90           0.70                0.70
# 1                      0.20       0.80           0.80                0.50
# 2                      1.00       1.00           1.00                1.00
# 3                      0.20       0.75           0.75                0.75
# 4                      0.20       0.00           0.80                0.50
# ..                      ...        ...            ...                 ...
# 157                    0.50       0.70           0.60                0.50
# 158                    0.00       0.70           0.70                0.00
# 159                    0.40       0.90           0.80                0.70
# 160                    0.20       0.40           0.70                0.70
# 161                    0.90       0.40           0.40                0.70
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                  0.80                   NaN
# 1                                  0.10                  0.20
# 2                                  1.00                  0.80
# 3                                  0.75                  0.75
# 4                                  0.60                  0.40
# ..                                  ...                   ...
# 157                                0.30                  0.70
# 158                                0.00                  0.00
# 159                                0.40                  0.50
# 160                                0.80                   NaN
# 161                                0.90                   NaN
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                              NaN                     NaN  ...
# 1                              NaN                     NaN  ...
# 2                              0.9                     1.0  ...
# 3                              NaN                     NaN  ...
# 4                              0.4                     0.2  ...
# ..                             ...                     ...  ...
# 157                            NaN                     NaN  ...
# 158                            NaN                     NaN  ...
# 159                            0.4                     0.2  ...
# 160                            NaN                     0.7  ...
# 161                            NaN                     0.8  ...
#
#      Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                          NaN                       NaN           NaN
# 1                          NaN                       NaN           NaN
# 2                          NaN                       NaN           NaN
# 3                          NaN                       NaN           NaN
# 4                          0.0                       0.0           0.0
# ..                         ...                       ...           ...
# 157                        NaN                       NaN           NaN
# 158                        NaN                       NaN           NaN
# 159                        NaN                       NaN           NaN
# 160                        NaN                       NaN           NaN
# 161                        NaN                       NaN           NaN
#
#      VLSI Architecture Design\n  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           0.0
# ..                          ...
# 157                         NaN
# 158                         NaN
# 159                         NaN
# 160                         NaN
# 161                         NaN
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  0.0
# ..                                                 ...
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0                   NaN                         0.6
# 1                   NaN                         0.5
# 2                   NaN                         0.4
# 3                   0.8                         NaN
# 4                   0.0                         0.0
# ..                  ...                         ...
# 157                 NaN                         0.0
# 158                 NaN                         NaN
# 159                 NaN                         1.0
# 160                 NaN                         NaN
# 161                 NaN                         NaN
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            0.8
# 4                          0.0                            0.0
# ..                         ...                            ...
# 157                        NaN                            NaN
# 158                        NaN                            NaN
# 159                        NaN                            NaN
# 160                        NaN                            NaN
# 161                        NaN                            NaN
#
#      The Web and the Mind
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      0.0
# ..                     ...
# 157                    NaN
# 158                    0.2
# 159                    1.0
# 160                    NaN
# 161                    NaN
#
# [162 rows x 25 columns]

# %%
X = df[[df.columns[0],df.columns[1],df.columns[2],df.columns[3],df.columns[4]]]
y = df.drop(labels=["Data Structures and Algorithms","Computer Architecture\n","Discrete Mathematics\n","Economics","Programming-2"],axis="columns")

# %%
X
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2
# 0                      0.85       0.90           0.70
# 1                      0.20       0.80           0.80
# 2                      1.00       1.00           1.00
# 3                      0.20       0.75           0.75
# 4                      0.20       0.00           0.80
# ..                      ...        ...            ...
# 157                    0.50       0.70           0.60
# 158                    0.00       0.70           0.70
# 159                    0.40       0.90           0.80
# 160                    0.20       0.40           0.70
# 161                    0.90       0.40           0.40
#
# [162 rows x 5 columns]

# %%
y
# Out:
#      Machine Learning\n  Mathematics For Machine Learning\n  \
# 0                  0.70                                0.80
# 1                  0.50                                0.10
# 2                  1.00                                1.00
# 3                  0.75                                0.75
# 4                  0.50                                0.60
# ..                  ...                                 ...
# 157                0.50                                0.30
# 158                0.00                                0.00
# 159                0.70                                0.40
# 160                0.70                                0.80
# 161                0.70                                0.90
#
#      Visual Recognition\n  Natural Language Processing\n  \
# 0                     NaN                            NaN
# 1                    0.20                            NaN
# 2                    0.80                            0.9
# 3                    0.75                            NaN
# 4                    0.40                            0.4
# ..                    ...                            ...
# 157                  0.70                            NaN
# 158                  0.00                            NaN
# 159                  0.50                            0.4
# 160                   NaN                            NaN
# 161                   NaN                            NaN
#
#      Reinforcement Learning  Software Production Engineering\n  \
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2                       1.0                                0.0
# 3                       NaN                                0.3
# 4                       0.2                                0.7
# ..                      ...                                ...
# 157                     NaN                                NaN
# 158                     NaN                                0.5
# 159                     0.2                                0.7
# 160                     0.7                                0.4
# 161                     0.8                                NaN
#
#      Computer Graphics\n  Data Visualization\n  Programming Languages\n  \
# 0                    NaN                   NaN                      NaN
# 1                    0.8                   NaN                      NaN
# 2                    0.6                   0.0                      0.0
# 3                    0.2                   NaN                      0.6
# 4                    0.2                   0.2                      0.5
# ..                   ...                   ...                      ...
# 157                  0.0                   NaN                      NaN
# 158                  1.0                   1.0                      0.0
# 159                  0.7                   0.7                      0.7
# 160                  0.4                   NaN                      0.6
# 161                  NaN                   NaN                      0.4
#
#      Cloud Computing\n  Digital CMOS VLSI Design   System design with FPGA   \
# 0                  NaN                        NaN                       NaN
# 1                  NaN                        NaN                       NaN
# 2                  0.0                        NaN                       NaN
# 3                  NaN                        NaN                       NaN
# 4                  0.3                        0.0                       0.0
# ..                 ...                        ...                       ...
# 157                NaN                        NaN                       NaN
# 158                NaN                        NaN                       NaN
# 159                0.8                        NaN                       NaN
# 160                NaN                        NaN                       NaN
# 161                NaN                        NaN                       NaN
#
#      ASIC design   VLSI Architecture Design\n  \
# 0             NaN                         NaN
# 1             NaN                         NaN
# 2             NaN                         NaN
# 3             NaN                         NaN
# 4             0.0                         0.0
# ..            ...                         ...
# 157           NaN                         NaN
# 158           NaN                         NaN
# 159           NaN                         NaN
# 160           NaN                         NaN
# 161           NaN                         NaN
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  0.0
# ..                                                 ...
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0                   NaN                         0.6
# 1                   NaN                         0.5
# 2                   NaN                         0.4
# 3                   0.8                         NaN
# 4                   0.0                         0.0
# ..                  ...                         ...
# 157                 NaN                         0.0
# 158                 NaN                         NaN
# 159                 NaN                         1.0
# 160                 NaN                         NaN
# 161                 NaN                         NaN
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            0.8
# 4                          0.0                            0.0
# ..                         ...                            ...
# 157                        NaN                            NaN
# 158                        NaN                            NaN
# 159                        NaN                            NaN
# 160                        NaN                            NaN
# 161                        NaN                            NaN
#
#      The Web and the Mind
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      0.0
# ..                     ...
# 157                    NaN
# 158                    0.2
# 159                    1.0
# 160                    NaN
# 161                    NaN
#
# [162 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.05, shuffle=True)

# %%
matrix,kmeans_model = cluster_to_matrix(X_train,y_train,4)

# %%
matrix
# Out:
# array([[0.8       , 0.67692308, 0.59230769, 0.61923077, 0.83384615,
#         0.85294118, 0.78676471, 0.66366667, 0.50217391, 0.71818182,
#         0.72608696, 0.40285714, 0.52857143, 0.47608696, 0.54782609,
#         0.24117647, 0.28125   , 0.24705882, 0.22941176, 0.16      ,
#         0.18823529, 0.36666667, 0.34375   , 0.34375   , 0.61111111],
#        [0.90769231, 0.70769231, 0.57692308, 0.48846154, 0.82307692,
#         0.78461538, 0.61538462, 0.50416667, 0.47222222, 0.57777778,
#         0.81      , 0.59      , 0.61111111, 0.54      , 0.725     ,
#         0.35714286, 0.47142857, 0.38571429, 0.35714286, 0.35      ,
#         0.325     , 0.46222222, 0.52166667, 0.325     , 0.40714286],
#        [0.74444444, 0.76111111, 0.42777778, 0.49444444, 0.87222222,
#         0.79444444, 0.80555556, 0.65      , 0.74857143, 0.77      ,
#         0.81875   , 0.37857143, 0.63571429, 0.6       , 0.6       ,
#         0.11666667, 0.1       , 0.1       , 0.1       , 0.08333333,
#         0.25714286, 0.45      , 0.25      , 0.42857143, 0.35      ],
#        [0.78411765, 0.78529412, 0.63764706, 0.77411765, 0.70882353,
#         0.74230769, 0.68214286, 0.56      , 0.74      , 0.51666667,
#         0.775     , 0.46666667, 0.61666667, 0.45714286, 0.61666667,
#         0.205     , 0.18      , 0.085     , 0.2125    , 0.        ,
#         0.5       , 0.62727273, 0.3       , 0.35      , 0.66666667]])

# %%
matrix.shape
# Out:
# (4, 25)

# %%
from SVD import * 
u,s,sigma,V_trans = SVD(matrix)
# Out:
# /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/index_tricks.py:910: ComplexWarning: Casting complex values to real discards the imaginary part
#   a.flat[:end:step] = val
# /Users/monjoy/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/SVD.py:136: ComplexWarning: Casting complex values to real discards the imaginary part
#   sigma[i, i] = s[i]

# %%
matrix_clean = u@sigma@V_trans
matrix_clean = matrix_clean.astype('float')
matrix_clean
# Out:
# /var/folders/d3/cp13q0jn14z64vh0k61msh680000gn/T/ipykernel_83074/1137659798.py:2: ComplexWarning: Casting complex values to real discards the imaginary part
#   matrix_clean = matrix_clean.astype('float')
# array([[8.00000000e-01, 6.76923077e-01, 5.92307692e-01, 6.19230769e-01,
#         8.33846154e-01, 8.52941176e-01, 7.86764706e-01, 6.63666667e-01,
#         5.02173913e-01, 7.18181818e-01, 7.26086957e-01, 4.02857143e-01,
#         5.28571429e-01, 4.76086957e-01, 5.47826087e-01, 2.41176471e-01,
#         2.81250000e-01, 2.47058824e-01, 2.29411765e-01, 1.60000000e-01,
#         1.88235294e-01, 3.66666667e-01, 3.43750000e-01, 3.43750000e-01,
#         6.11111111e-01],
#        [9.07692308e-01, 7.07692308e-01, 5.76923077e-01, 4.88461538e-01,
#         8.23076923e-01, 7.84615385e-01, 6.15384615e-01, 5.04166667e-01,
#         4.72222222e-01, 5.77777778e-01, 8.10000000e-01, 5.90000000e-01,
#         6.11111111e-01, 5.40000000e-01, 7.25000000e-01, 3.57142857e-01,
#         4.71428571e-01, 3.85714286e-01, 3.57142857e-01, 3.50000000e-01,
#         3.25000000e-01, 4.62222222e-01, 5.21666667e-01, 3.25000000e-01,
#         4.07142857e-01],
#        [7.44444444e-01, 7.61111111e-01, 4.27777778e-01, 4.94444444e-01,
#         8.72222222e-01, 7.94444444e-01, 8.05555556e-01, 6.50000000e-01,
#         7.48571429e-01, 7.70000000e-01, 8.18750000e-01, 3.78571429e-01,
#         6.35714286e-01, 6.00000000e-01, 6.00000000e-01, 1.16666667e-01,
#         1.00000000e-01, 1.00000000e-01, 1.00000000e-01, 8.33333333e-02,
#         2.57142857e-01, 4.50000000e-01, 2.50000000e-01, 4.28571429e-01,
#         3.50000000e-01],
#        [7.84117647e-01, 7.85294118e-01, 6.37647059e-01, 7.74117647e-01,
#         7.08823529e-01, 7.42307692e-01, 6.82142857e-01, 5.60000000e-01,
#         7.40000000e-01, 5.16666667e-01, 7.75000000e-01, 4.66666667e-01,
#         6.16666667e-01, 4.57142857e-01, 6.16666667e-01, 2.05000000e-01,
#         1.80000000e-01, 8.50000000e-02, 2.12500000e-01, 4.70543743e-17,
#         5.00000000e-01, 6.27272727e-01, 3.00000000e-01, 3.50000000e-01,
#         6.66666667e-01]])

# %%
def predict(datapoint,kmeans,matrix_clean):
    ''' 
        @input: Takes in a datapoint, kmeans object, and information matrix 
        @output: Returns: rating sorted with index for column name mapping
    '''
    y_pred = kmeans.predictPoint(datapoint)
    inferred_full = matrix_clean[y_pred]
    inferred = inferred_full[5:]
    sorted_ratings = []
    for idx,element in enumerate(inferred):
        sorted_ratings.append([element,idx+5])
    sorted_ratings.sort()
    sorted_ratings.reverse()
    return sorted_ratings

# %%
y_test
# Out:
#      Machine Learning\n  Mathematics For Machine Learning\n  \
# 33                 0.80                                0.30
# 28                 0.80                                0.70
# 129                1.00                                1.00
# 145                1.00                                1.00
# 147                0.90                                0.80
# 15                 1.00                                0.80
# 64                 0.50                                1.00
# 95                 1.00                                0.00
# 101                1.00                                1.00
# 89                 0.00                                0.00
# 57                  NaN                                 NaN
# 152                1.00                                0.60
# 94                 1.00                                1.00
# 66                 0.00                                0.00
# 49                 0.80                                0.80
# 40                 0.80                                0.70
# 155                0.80                                0.40
# 110                1.00                                1.00
# 16                 0.90                                0.80
# 107                0.50                                0.30
# 37                 0.90                                0.70
# 102                0.40                                0.20
# 118                1.00                                1.00
# 91                 1.00                                1.00
# 39                 0.60                                0.80
# 62                 1.00                                1.00
# 84                 1.00                                1.00
# 24                 0.90                                0.90
# 149                 NaN                                 NaN
# 146                 NaN                                 NaN
# 154                1.00                                1.00
# 115                1.00                                1.00
# 93                 0.50                                0.70
# 68                 0.80                                1.00
# 22                 1.00                                1.00
# 52                 1.00                                1.00
# 120                1.00                                1.00
# 142                1.00                                0.00
# 80                 0.80                                0.65
# 108                1.00                                1.00
# 3                  0.75                                0.75
# 44                 1.00                                0.80
# 130                 NaN                                 NaN
# 17                 0.60                                0.70
# 97                 1.00                                1.00
# 143                0.00                                0.00
# 70                  NaN                                 NaN
# 103                1.00                                1.00
# 4                  0.50                                0.60
#
#      Visual Recognition\n  Natural Language Processing\n  \
# 33                   0.60                            0.8
# 28                   0.60                            0.5
# 129                  0.00                            0.0
# 145                   NaN                            0.8
# 147                  0.70                            NaN
# 15                   0.70                            NaN
# 64                   0.50                            0.5
# 95                   1.00                            1.0
# 101                  1.00                            0.5
# 89                   0.00                            0.0
# 57                    NaN                            NaN
# 152                  1.00                            0.3
# 94                   0.60                            0.8
# 66                   0.00                            0.0
# 49                   0.50                            0.3
# 40                   0.50                            NaN
# 155                  0.70                            0.8
# 110                  1.00                            1.0
# 16                   0.60                            0.5
# 107                  0.50                            0.5
# 37                   0.80                            0.7
# 102                  0.20                            0.2
# 118                  1.00                            1.0
# 91                   0.80                            0.9
# 39                    NaN                            NaN
# 62                   1.00                            1.0
# 84                   0.50                            0.0
# 24                   0.80                            NaN
# 149                   NaN                            NaN
# 146                   NaN                            NaN
# 154                  1.00                            1.0
# 115                  1.00                            NaN
# 93                   0.20                            NaN
# 68                   0.80                            0.8
# 22                   0.50                            NaN
# 52                   1.00                            1.0
# 120                  0.00                            1.0
# 142                  0.00                            1.0
# 80                   0.70                            0.4
# 108                  1.00                            1.0
# 3                    0.75                            NaN
# 44                   0.60                            NaN
# 130                   NaN                            NaN
# 17                    NaN                            NaN
# 97                   0.60                            NaN
# 143                  0.00                            0.0
# 70                    NaN                            NaN
# 103                  0.75                            0.6
# 4                    0.40                            0.4
#
#      Reinforcement Learning  Software Production Engineering\n  \
# 33                      0.2                                0.8
# 28                      0.3                                0.3
# 129                     1.0                                0.0
# 145                     NaN                                NaN
# 147                     NaN                                0.9
# 15                      NaN                                NaN
# 64                      1.0                                1.0
# 95                      1.0                                0.0
# 101                     0.5                                0.8
# 89                      0.0                                1.0
# 57                      NaN                                NaN
# 152                     0.0                                0.2
# 94                      1.0                                1.0
# 66                      0.0                                0.0
# 49                      0.4                                0.2
# 40                      NaN                                NaN
# 155                     1.0                                0.8
# 110                     1.0                                0.0
# 16                      0.6                                NaN
# 107                     0.3                                1.0
# 37                      0.8                                0.8
# 102                     0.6                                0.3
# 118                     1.0                                0.4
# 91                      0.9                                0.7
# 39                      NaN                                0.9
# 62                      1.0                                0.0
# 84                      1.0                                1.0
# 24                      NaN                                0.5
# 149                     NaN                                NaN
# 146                     NaN                                NaN
# 154                     0.0                                1.0
# 115                     NaN                                NaN
# 93                      NaN                                NaN
# 68                      1.0                                0.2
# 22                      NaN                                NaN
# 52                      0.0                                0.0
# 120                     0.0                                1.0
# 142                     1.0                                1.0
# 80                      0.5                                0.8
# 108                     1.0                                0.0
# 3                       NaN                                0.3
# 44                      NaN                                NaN
# 130                     NaN                                NaN
# 17                      NaN                                NaN
# 97                      NaN                                NaN
# 143                     0.0                                1.0
# 70                      NaN                                NaN
# 103                     0.5                                1.0
# 4                       0.2                                0.7
#
#      Computer Graphics\n  Data Visualization\n  Programming Languages\n  \
# 33                  0.30                  0.50                     0.80
# 28                  0.50                  0.40                     0.50
# 129                 0.00                  0.50                     0.30
# 145                  NaN                   NaN                     0.30
# 147                  NaN                  0.50                     0.30
# 15                  1.00                   NaN                     0.80
# 64                  1.00                  0.50                     1.00
# 95                  0.00                  1.00                     0.00
# 101                 0.30                  0.90                     0.80
# 89                  0.00                  0.20                     1.00
# 57                   NaN                   NaN                      NaN
# 152                 0.70                  0.80                     1.00
# 94                  0.20                  0.70                     0.50
# 66                  0.00                  0.00                     0.00
# 49                  0.40                  0.40                     0.40
# 40                   NaN                   NaN                      NaN
# 155                 1.00                  1.00                     0.60
# 110                 0.00                  0.00                     0.00
# 16                   NaN                   NaN                      NaN
# 107                 0.10                  0.70                     0.00
# 37                  0.80                  0.90                     0.85
# 102                 0.20                  0.30                     0.50
# 118                 0.50                  0.20                     0.60
# 91                  0.60                  0.30                     1.00
# 39                   NaN                   NaN                      NaN
# 62                  0.00                  1.00                     1.00
# 84                  1.00                  0.70                     1.00
# 24                  0.80                   NaN                      NaN
# 149                  NaN                   NaN                      NaN
# 146                  NaN                   NaN                      NaN
# 154                 0.00                  0.00                     1.00
# 115                  NaN                   NaN                     1.00
# 93                  0.70                  1.00                     0.50
# 68                  0.70                  0.40                     0.20
# 22                   NaN                   NaN                     0.80
# 52                  1.00                  1.00                     1.00
# 120                 0.00                  0.00                     0.00
# 142                 0.00                  0.00                     1.00
# 80                  0.00                  0.50                     0.60
# 108                 0.00                  0.00                     1.00
# 3                   0.20                   NaN                     0.60
# 44                   NaN                   NaN                     0.70
# 130                  NaN                   NaN                      NaN
# 17                  0.90                   NaN                     0.90
# 97                  0.80                   NaN                     0.00
# 143                 0.00                  0.00                     1.00
# 70                   NaN                   NaN                      NaN
# 103                 0.35                  0.45                     0.00
# 4                   0.20                  0.20                     0.50
#
#      Cloud Computing\n  Digital CMOS VLSI Design   System design with FPGA   \
# 33                 0.6                        0.2                       0.1
# 28                 0.4                        0.1                       0.1
# 129                0.0                        0.0                       NaN
# 145                NaN                        NaN                       NaN
# 147                0.2                        NaN                       NaN
# 15                 NaN                        NaN                       NaN
# 64                 1.0                        0.0                       0.0
# 95                 1.0                        0.0                       0.0
# 101                0.9                        0.0                       0.0
# 89                 1.0                        0.0                       0.0
# 57                 NaN                        NaN                       NaN
# 152                0.3                        1.0                       1.0
# 94                 0.6                        0.0                       0.0
# 66                 0.0                        1.0                       1.0
# 49                 0.5                        0.3                       0.4
# 40                 NaN                        NaN                       NaN
# 155                0.5                        0.0                       0.0
# 110                0.0                        1.0                       0.5
# 16                 NaN                        0.0                       0.0
# 107                0.6                        0.0                       0.0
# 37                 0.7                        0.6                       0.6
# 102                0.6                        0.0                       0.0
# 118                0.7                        0.0                       0.0
# 91                 1.0                        NaN                       0.3
# 39                 NaN                        NaN                       NaN
# 62                 1.0                        1.0                       1.0
# 84                 1.0                        0.0                       0.0
# 24                 NaN                        NaN                       NaN
# 149                NaN                        NaN                       NaN
# 146                NaN                        NaN                       NaN
# 154                1.0                        NaN                       NaN
# 115                NaN                        NaN                       NaN
# 93                 NaN                        NaN                       NaN
# 68                 0.4                        0.1                       0.1
# 22                 NaN                        NaN                       NaN
# 52                 1.0                        0.0                       0.0
# 120                0.0                        0.0                       0.0
# 142                0.0                        0.0                       0.0
# 80                 0.8                        NaN                       NaN
# 108                0.0                        0.0                       0.0
# 3                  NaN                        NaN                       NaN
# 44                 NaN                        NaN                       NaN
# 130                NaN                        NaN                       NaN
# 17                 0.8                        NaN                       NaN
# 97                 NaN                        NaN                       NaN
# 143                0.0                        NaN                       NaN
# 70                 NaN                        NaN                       NaN
# 103                0.5                        NaN                       NaN
# 4                  0.3                        0.0                       0.0
#
#      ASIC design   VLSI Architecture Design\n  \
# 33            0.0                         0.0
# 28            0.2                         0.1
# 129           NaN                         NaN
# 145           NaN                         NaN
# 147           NaN                         NaN
# 15            NaN                         NaN
# 64            0.0                         0.0
# 95            0.0                         0.0
# 101           0.0                         0.0
# 89            0.0                         0.0
# 57            NaN                         NaN
# 152           1.0                         1.0
# 94            0.0                         0.0
# 66            1.0                         1.0
# 49            0.3                         0.3
# 40            NaN                         NaN
# 155           0.0                         0.5
# 110           1.0                         1.0
# 16            0.0                         0.0
# 107           0.0                         0.0
# 37            0.7                         0.6
# 102           0.0                         0.0
# 118           0.0                         0.0
# 91            0.0                         NaN
# 39            NaN                         NaN
# 62            1.0                         1.0
# 84            0.0                         0.0
# 24            NaN                         NaN
# 149           NaN                         NaN
# 146           NaN                         NaN
# 154           NaN                         NaN
# 115           NaN                         NaN
# 93            NaN                         NaN
# 68            0.0                         0.0
# 22            NaN                         NaN
# 52            0.0                         0.0
# 120           0.0                         0.0
# 142           0.0                         0.0
# 80            NaN                         NaN
# 108           0.0                         0.0
# 3             NaN                         NaN
# 44            NaN                         NaN
# 130           NaN                         NaN
# 17            NaN                         NaN
# 97            NaN                         NaN
# 143           NaN                         NaN
# 70            NaN                         NaN
# 103           NaN                         NaN
# 4             0.0                         0.0
#
#      High level synthesis and optimization of Digital Circuits   \
# 33                                                 0.2
# 28                                                 0.2
# 129                                                NaN
# 145                                                NaN
# 147                                                NaN
# 15                                                 NaN
# 64                                                 0.0
# 95                                                 0.0
# 101                                                0.0
# 89                                                 0.0
# 57                                                 NaN
# 152                                                1.0
# 94                                                 0.0
# 66                                                 0.0
# 49                                                 0.3
# 40                                                 NaN
# 155                                                0.0
# 110                                                1.0
# 16                                                 0.0
# 107                                                0.0
# 37                                                 0.6
# 102                                                0.0
# 118                                                0.0
# 91                                                 NaN
# 39                                                 NaN
# 62                                                 1.0
# 84                                                 0.0
# 24                                                 NaN
# 149                                                NaN
# 146                                                NaN
# 154                                                NaN
# 115                                                NaN
# 93                                                 NaN
# 68                                                 0.3
# 22                                                 NaN
# 52                                                 0.0
# 120                                                0.0
# 142                                                0.0
# 80                                                 NaN
# 108                                                0.0
# 3                                                  NaN
# 44                                                 NaN
# 130                                                NaN
# 17                                                 NaN
# 97                                                 NaN
# 143                                                NaN
# 70                                                 NaN
# 103                                                NaN
# 4                                                  0.0
#
#      Digital Sociology   Privacy in the Digital Age  \
# 33                 0.00                        0.70
# 28                 0.50                        0.40
# 129                 NaN                         NaN
# 145                 NaN                        0.40
# 147                 NaN                         NaN
# 15                  NaN                        0.60
# 64                 0.00                        0.00
# 95                 1.00                        1.00
# 101                0.00                        0.60
# 89                 0.00                        0.00
# 57                  NaN                         NaN
# 152                0.40                        0.80
# 94                 0.00                        0.50
# 66                  NaN                         NaN
# 49                 0.50                        0.50
# 40                  NaN                        0.55
# 155                0.00                        0.00
# 110                0.00                        0.00
# 16                 0.00                        0.70
# 107                1.00                        1.00
# 37                 0.55                        0.70
# 102                0.50                        0.00
# 118                0.05                        0.60
# 91                  NaN                         NaN
# 39                  NaN                        0.70
# 62                  NaN                         NaN
# 84                  NaN                         NaN
# 24                  NaN                         NaN
# 149                 NaN                         NaN
# 146                 NaN                         NaN
# 154                 NaN                         NaN
# 115                 NaN                         NaN
# 93                 1.00                         NaN
# 68                 0.00                        0.40
# 22                  NaN                        0.10
# 52                 0.00                        1.00
# 120                0.00                        0.00
# 142                1.00                        1.00
# 80                  NaN                         NaN
# 108                0.00                        0.00
# 3                  0.80                         NaN
# 44                  NaN                        0.60
# 130                 NaN                         NaN
# 17                  NaN                        0.70
# 97                  NaN                        0.70
# 143                1.00                        1.00
# 70                  NaN                         NaN
# 103                 NaN                         NaN
# 4                  0.00                        0.00
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 33                         0.8                            0.6
# 28                         0.7                            0.5
# 129                        0.3                            NaN
# 145                        NaN                            0.8
# 147                        NaN                            NaN
# 15                         NaN                            NaN
# 64                         0.0                            0.0
# 95                         1.0                            1.0
# 101                        0.0                            0.0
# 89                         0.0                            0.0
# 57                         NaN                            NaN
# 152                        1.0                            0.1
# 94                         0.5                            0.0
# 66                         NaN                            NaN
# 49                         0.4                            0.6
# 40                         NaN                            NaN
# 155                        0.0                            0.0
# 110                        0.0                            0.0
# 16                         0.4                            0.3
# 107                        1.0                            1.0
# 37                         0.7                            0.7
# 102                        0.6                            0.1
# 118                        0.7                            0.0
# 91                         NaN                            NaN
# 39                         NaN                            NaN
# 62                         NaN                            NaN
# 84                         NaN                            NaN
# 24                         NaN                            NaN
# 149                        NaN                            NaN
# 146                        NaN                            NaN
# 154                        NaN                            NaN
# 115                        NaN                            NaN
# 93                         0.3                            NaN
# 68                         0.6                            0.8
# 22                         NaN                            NaN
# 52                         0.0                            0.0
# 120                        0.0                            0.0
# 142                        1.0                            0.0
# 80                         NaN                            NaN
# 108                        0.0                            0.0
# 3                          NaN                            0.8
# 44                         NaN                            NaN
# 130                        NaN                            NaN
# 17                         NaN                            NaN
# 97                         NaN                            1.0
# 143                        NaN                            1.0
# 70                         NaN                            NaN
# 103                        NaN                            NaN
# 4                          0.0                            0.0
#
#      The Web and the Mind
# 33                    0.20
# 28                    0.80
# 129                    NaN
# 145                    NaN
# 147                    NaN
# 15                     NaN
# 64                    1.00
# 95                    1.00
# 101                   0.30
# 89                    0.20
# 57                     NaN
# 152                   0.50
# 94                    0.60
# 66                     NaN
# 49                    0.60
# 40                     NaN
# 155                   0.00
# 110                   0.75
# 16                    0.70
# 107                   1.00
# 37                    0.75
# 102                   0.60
# 118                   0.20
# 91                     NaN
# 39                     NaN
# 62                     NaN
# 84                    1.00
# 24                     NaN
# 149                    NaN
# 146                    NaN
# 154                    NaN
# 115                    NaN
# 93                    0.80
# 68                    0.70
# 22                     NaN
# 52                    1.00
# 120                   0.00
# 142                   1.00
# 80                     NaN
# 108                   0.00
# 3                      NaN
# 44                     NaN
# 130                    NaN
# 17                     NaN
# 97                     NaN
# 143                    NaN
# 70                     NaN
# 103                    NaN
# 4                     0.00

# %% [markdown]
# Trying Prediction on a sample data point from test set

# %%
X_test.to_numpy()[0][:5]
# Out:
# array([0.3, 0.6, 0.7, 1. , 0.9])

# %%
sorted_ratings = predict(X_test.to_numpy()[7][:5],kmeans_model,matrix_clean)

# %%
s="Top 5 recommended electives are:\n"
for i in range(5):
    s+=df.columns[sorted_ratings[i][1]]
print(s)
# Out:
# Top 5 recommended electives are:
# Machine Learning
# Mathematics For Machine Learning
# Software Production Engineering
# Reinforcement LearningVisual Recognition

# %% [markdown]
# Comparing sample with the actual top 5

# %%
inferred = y_test.to_numpy()[0]
for idx,element in enumerate(inferred):
    sorted_ratings.append([element,idx+5])
sorted_ratings.sort()
sorted_ratings.reverse()


s="Top 5 ACTUAL recommended electives are:\n"
for i in range(5):
    s+=df.columns[sorted_ratings[i][1]]
print(s)
# Out:
# Top 5 ACTUAL recommended electives are:
# Machine Learning
# Technology Ethics and AI Programming Languages
# Software Production Engineering
# Natural Language Processing
