# %% [markdown]
# ## Course Reccomendation System

# %%
from __future__ import annotations # To prevent Subscript for class "list" will generate runtime exception; enclose type annotation in quotes
import seaborn as sns
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import random
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import scipy
from sklearn.preprocessing import MinMaxScaler
from Kmeans import * 
# %matplotlib inline

# %%
random_state = 42

# %% [markdown]
# #### Applying Pre-processing steps on data:

# %%
df=pd.read_excel('Course Recommendation System.xlsx')
df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1)
df['mean'] = df.mean(axis=0,skipna=True,numeric_only=True)
df = df.apply(lambda x : x.fillna(x.mean(skipna=True)),axis=0)
df.drop(axis="columns",labels=["mean"],inplace=True)
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                      0.85       0.90           0.70                0.70
# 1                      0.20       0.80           0.80                0.50
# 2                      1.00       1.00           1.00                1.00
# 3                      0.20       0.75           0.75                0.75
# 4                      0.20       0.00           0.80                0.50
# ..                      ...        ...            ...                 ...
# 157                    0.50       0.70           0.60                0.50
# 158                    0.00       0.70           0.70                0.00
# 159                    0.40       0.90           0.80                0.70
# 160                    0.20       0.40           0.70                0.70
# 161                    0.90       0.40           0.40                0.70
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                  0.80              0.620098
# 1                                  0.10              0.200000
# 2                                  1.00              0.800000
# 3                                  0.75              0.750000
# 4                                  0.60              0.400000
# ..                                  ...                   ...
# 157                                0.30              0.700000
# 158                                0.00              0.000000
# 159                                0.40              0.500000
# 160                                0.80              0.620098
# 161                                0.90              0.620098
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                         0.572638                0.603495  ...
# 1                         0.572638                0.603495  ...
# 2                         0.900000                1.000000  ...
# 3                         0.572638                0.603495  ...
# 4                         0.400000                0.200000  ...
# ..                             ...                     ...  ...
# 157                       0.572638                0.603495  ...
# 158                       0.572638                0.603495  ...
# 159                       0.400000                0.200000  ...
# 160                       0.572638                0.700000  ...
# 161                       0.572638                0.800000  ...
#
#      Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                     0.251538                  0.246316      0.214805
# 1                     0.251538                  0.246316      0.214805
# 2                     0.251538                  0.246316      0.214805
# 3                     0.251538                  0.246316      0.214805
# 4                     0.000000                  0.000000      0.000000
# ..                         ...                       ...           ...
# 157                   0.251538                  0.246316      0.214805
# 158                   0.251538                  0.246316      0.214805
# 159                   0.251538                  0.246316      0.214805
# 160                   0.251538                  0.246316      0.214805
# 161                   0.251538                  0.246316      0.214805
#
#      VLSI Architecture Design\n  \
# 0                      0.234868
# 1                      0.234868
# 2                      0.234868
# 3                      0.234868
# 4                      0.000000
# ..                          ...
# 157                    0.234868
# 158                    0.234868
# 159                    0.234868
# 160                    0.234868
# 161                    0.234868
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                             0.168056
# 1                                             0.168056
# 2                                             0.168056
# 3                                             0.168056
# 4                                             0.000000
# ..                                                 ...
# 157                                           0.168056
# 158                                           0.168056
# 159                                           0.168056
# 160                                           0.168056
# 161                                           0.168056
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0              0.318243                    0.600000
# 1              0.318243                    0.500000
# 2              0.318243                    0.400000
# 3              0.800000                    0.452708
# 4              0.000000                    0.000000
# ..                  ...                         ...
# 157            0.318243                    0.000000
# 158            0.318243                    0.452708
# 159            0.318243                    1.000000
# 160            0.318243                    0.452708
# 161            0.318243                    0.452708
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                     0.423286                       0.396622
# 1                     0.423286                       0.396622
# 2                     0.423286                       0.396622
# 3                     0.423286                       0.800000
# 4                     0.000000                       0.000000
# ..                         ...                            ...
# 157                   0.423286                       0.396622
# 158                   0.423286                       0.396622
# 159                   0.423286                       0.396622
# 160                   0.423286                       0.396622
# 161                   0.423286                       0.396622
#
#      The Web and the Mind
# 0                 0.510897
# 1                 0.510897
# 2                 0.510897
# 3                 0.510897
# 4                 0.000000
# ..                     ...
# 157               0.510897
# 158               0.200000
# 159               1.000000
# 160               0.510897
# 161               0.510897
#
# [162 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Data Structures and Algorithms', 'Computer Architecture\n',
#        'Discrete Mathematics\n', 'Economics', 'Programming-2',
#        'Machine Learning\n', 'Mathematics For Machine Learning\n',
#        'Visual Recognition\n', 'Natural Language Processing\n',
#        'Reinforcement Learning', 'Software Production Engineering\n',
#        'Computer Graphics\n', 'Data Visualization\n',
#        'Programming Languages\n', 'Cloud Computing\n',
#        'Digital CMOS VLSI Design ', 'System design with FPGA ', 'ASIC design ',
#        'VLSI Architecture Design\n',
#        'High level synthesis and optimization of Digital Circuits ',
#        'Digital Sociology ', 'Privacy in the Digital Age',
#        'Technology Ethics and AI ', 'Techno-economics of networks ',
#        'The Web and the Mind '],
#       dtype='object')

# %%
def cluster_to_matrix(X_train,y_train,num_cluster):
    k=Kmeans(K=num_cluster,iter=150,p=2,random_state=random_state)
    y_pred=k.predict(np.array(X_train),choice=0)
    k.centroids=np.array(k.centroids, dtype='int')
    X_train2 = pd.concat([X_train,y_train,pd.DataFrame(y_pred,columns=["label"],dtype='int')],axis="columns")
    df_cluster_rep = X_train2.groupby(['label'], as_index=False).mean()
    df_cluster_rep.drop(labels="label",axis="columns",inplace=True)
    matrix = df_cluster_rep.to_numpy()
    return matrix,k

# %% [markdown]
# Performing the task on dataset

# %%
X = df[[df.columns[0],df.columns[1],df.columns[2],df.columns[3],df.columns[4]]]
y = df.drop(labels=["Data Structures and Algorithms","Computer Architecture\n","Discrete Mathematics\n","Economics","Programming-2"],axis="columns")

# %%
X
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2
# 0                      0.85       0.90           0.70
# 1                      0.20       0.80           0.80
# 2                      1.00       1.00           1.00
# 3                      0.20       0.75           0.75
# 4                      0.20       0.00           0.80
# ..                      ...        ...            ...
# 157                    0.50       0.70           0.60
# 158                    0.00       0.70           0.70
# 159                    0.40       0.90           0.80
# 160                    0.20       0.40           0.70
# 161                    0.90       0.40           0.40
#
# [162 rows x 5 columns]

# %%
y
# Out:
#      Machine Learning\n  Mathematics For Machine Learning\n  \
# 0                  0.70                                0.80
# 1                  0.50                                0.10
# 2                  1.00                                1.00
# 3                  0.75                                0.75
# 4                  0.50                                0.60
# ..                  ...                                 ...
# 157                0.50                                0.30
# 158                0.00                                0.00
# 159                0.70                                0.40
# 160                0.70                                0.80
# 161                0.70                                0.90
#
#      Visual Recognition\n  Natural Language Processing\n  \
# 0                0.620098                       0.572638
# 1                0.200000                       0.572638
# 2                0.800000                       0.900000
# 3                0.750000                       0.572638
# 4                0.400000                       0.400000
# ..                    ...                            ...
# 157              0.700000                       0.572638
# 158              0.000000                       0.572638
# 159              0.500000                       0.400000
# 160              0.620098                       0.572638
# 161              0.620098                       0.572638
#
#      Reinforcement Learning  Software Production Engineering\n  \
# 0                  0.603495                           0.675943
# 1                  0.603495                           0.675943
# 2                  1.000000                           0.000000
# 3                  0.603495                           0.300000
# 4                  0.200000                           0.700000
# ..                      ...                                ...
# 157                0.603495                           0.675943
# 158                0.603495                           0.500000
# 159                0.200000                           0.700000
# 160                0.700000                           0.400000
# 161                0.800000                           0.675943
#
#      Computer Graphics\n  Data Visualization\n  Programming Languages\n  \
# 0               0.456217               0.58841                 0.543363
# 1               0.800000               0.58841                 0.543363
# 2               0.600000               0.00000                 0.000000
# 3               0.200000               0.58841                 0.600000
# 4               0.200000               0.20000                 0.500000
# ..                   ...                   ...                      ...
# 157             0.000000               0.58841                 0.543363
# 158             1.000000               1.00000                 0.000000
# 159             0.700000               0.70000                 0.700000
# 160             0.400000               0.58841                 0.600000
# 161             0.456217               0.58841                 0.400000
#
#      Cloud Computing\n  Digital CMOS VLSI Design   System design with FPGA   \
# 0             0.572587                   0.251538                  0.246316
# 1             0.572587                   0.251538                  0.246316
# 2             0.000000                   0.251538                  0.246316
# 3             0.572587                   0.251538                  0.246316
# 4             0.300000                   0.000000                  0.000000
# ..                 ...                        ...                       ...
# 157           0.572587                   0.251538                  0.246316
# 158           0.572587                   0.251538                  0.246316
# 159           0.800000                   0.251538                  0.246316
# 160           0.572587                   0.251538                  0.246316
# 161           0.572587                   0.251538                  0.246316
#
#      ASIC design   VLSI Architecture Design\n  \
# 0        0.214805                    0.234868
# 1        0.214805                    0.234868
# 2        0.214805                    0.234868
# 3        0.214805                    0.234868
# 4        0.000000                    0.000000
# ..            ...                         ...
# 157      0.214805                    0.234868
# 158      0.214805                    0.234868
# 159      0.214805                    0.234868
# 160      0.214805                    0.234868
# 161      0.214805                    0.234868
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                             0.168056
# 1                                             0.168056
# 2                                             0.168056
# 3                                             0.168056
# 4                                             0.000000
# ..                                                 ...
# 157                                           0.168056
# 158                                           0.168056
# 159                                           0.168056
# 160                                           0.168056
# 161                                           0.168056
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0              0.318243                    0.600000
# 1              0.318243                    0.500000
# 2              0.318243                    0.400000
# 3              0.800000                    0.452708
# 4              0.000000                    0.000000
# ..                  ...                         ...
# 157            0.318243                    0.000000
# 158            0.318243                    0.452708
# 159            0.318243                    1.000000
# 160            0.318243                    0.452708
# 161            0.318243                    0.452708
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                     0.423286                       0.396622
# 1                     0.423286                       0.396622
# 2                     0.423286                       0.396622
# 3                     0.423286                       0.800000
# 4                     0.000000                       0.000000
# ..                         ...                            ...
# 157                   0.423286                       0.396622
# 158                   0.423286                       0.396622
# 159                   0.423286                       0.396622
# 160                   0.423286                       0.396622
# 161                   0.423286                       0.396622
#
#      The Web and the Mind
# 0                 0.510897
# 1                 0.510897
# 2                 0.510897
# 3                 0.510897
# 4                 0.000000
# ..                     ...
# 157               0.510897
# 158               0.200000
# 159               1.000000
# 160               0.510897
# 161               0.510897
#
# [162 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.05, shuffle=True,random_state=random_state)

# %%
matrix,kmeans_model = cluster_to_matrix(X_train,y_train,4)

# %%
matrix
# Out:
# array([[0.78041201, 0.69484375, 0.62519303, 0.58660201, 0.85434184,
#         0.78983095, 0.72204211, 0.61568974, 0.60999638, 0.65391289,
#         0.66135024, 0.47760708, 0.6529633 , 0.58344856, 0.6202494 ,
#         0.3034976 , 0.27335526, 0.21161526, 0.26672492, 0.17371962,
#         0.30479307, 0.50122714, 0.40950223, 0.39804688, 0.54909856],
#        [0.78166667, 0.65733333, 0.56666667, 0.62833333, 0.824     ,
#         0.85010966, 0.72027039, 0.61569268, 0.48965241, 0.58519757,
#         0.63451258, 0.49082011, 0.5916443 , 0.52923304, 0.51812103,
#         0.23425641, 0.24754386, 0.2265368 , 0.23657895, 0.21537037,
#         0.37822072, 0.44977776, 0.47141429, 0.43452703, 0.59023504],
#        [0.86086957, 0.64347826, 0.6673913 , 0.50217391, 0.8673913 ,
#         0.76579663, 0.65848586, 0.5995737 , 0.4687437 , 0.52715079,
#         0.78293683, 0.36058776, 0.53409127, 0.60261639, 0.67503783,
#         0.16602007, 0.17633867, 0.13815923, 0.148627  , 0.12681159,
#         0.3166275 , 0.39691122, 0.44287578, 0.39186251, 0.4020903 ],
#        [0.83571429, 0.73571429, 0.63035714, 0.63035714, 0.90714286,
#         0.85202361, 0.76687812, 0.63608188, 0.68387382, 0.6184987 ,
#         0.62877358, 0.47333995, 0.51275998, 0.45774336, 0.47886104,
#         0.2631044 , 0.26270677, 0.29867347, 0.26012688, 0.17202381,
#         0.32340734, 0.43103422, 0.43307143, 0.43771718, 0.49613095]])

# %%
matrix.shape
# Out:
# (4, 25)

# %%
from SVD import * 
u,s,sigma,V_trans = SVD(matrix)

# %%
matrix_clean = u@sigma@V_trans
matrix_clean = matrix_clean.astype('float')
matrix_clean
# Out:
# array([[0.78041201, 0.69484375, 0.62519303, 0.58660201, 0.85434184,
#         0.78983095, 0.72204211, 0.61568974, 0.60999638, 0.65391289,
#         0.66135024, 0.47760708, 0.6529633 , 0.58344856, 0.6202494 ,
#         0.3034976 , 0.27335526, 0.21161526, 0.26672492, 0.17371962,
#         0.30479307, 0.50122714, 0.40950223, 0.39804688, 0.54909856],
#        [0.78166667, 0.65733333, 0.56666667, 0.62833333, 0.824     ,
#         0.85010966, 0.72027039, 0.61569268, 0.48965241, 0.58519757,
#         0.63451258, 0.49082011, 0.5916443 , 0.52923304, 0.51812103,
#         0.23425641, 0.24754386, 0.2265368 , 0.23657895, 0.21537037,
#         0.37822072, 0.44977776, 0.47141429, 0.43452703, 0.59023504],
#        [0.86086957, 0.64347826, 0.6673913 , 0.50217391, 0.8673913 ,
#         0.76579663, 0.65848586, 0.5995737 , 0.4687437 , 0.52715079,
#         0.78293683, 0.36058776, 0.53409127, 0.60261639, 0.67503783,
#         0.16602007, 0.17633867, 0.13815923, 0.148627  , 0.12681159,
#         0.3166275 , 0.39691122, 0.44287578, 0.39186251, 0.4020903 ],
#        [0.83571429, 0.73571429, 0.63035714, 0.63035714, 0.90714286,
#         0.85202361, 0.76687812, 0.63608188, 0.68387382, 0.6184987 ,
#         0.62877358, 0.47333995, 0.51275998, 0.45774336, 0.47886104,
#         0.2631044 , 0.26270677, 0.29867347, 0.26012688, 0.17202381,
#         0.32340734, 0.43103422, 0.43307143, 0.43771718, 0.49613095]])

# %%
def predict(datapoint,kmeans,matrix_clean):
    ''' 
        @input: Takes in a datapoint, kmeans object, and information matrix 
        @output: Returns: rating sorted with index for column name mapping
    '''
    y_pred = kmeans.predictPoint(datapoint)
    inferred_full = matrix_clean[y_pred]
    inferred = inferred_full[5:]
    sorted_ratings = []
    for idx,element in enumerate(inferred):
        sorted_ratings.append([element,idx+5])
    sorted_ratings.sort()
    sorted_ratings.reverse()
    return sorted_ratings

# %%
X_test.shape
# Out:
# (9, 5)

# %%
y_test
# Out:
#      Machine Learning\n  Mathematics For Machine Learning\n  \
# 158                0.00                                 0.0
# 109                0.75                                 0.8
# 131                0.60                                 0.7
# 55                 1.00                                 1.0
# 94                 1.00                                 1.0
# 29                 1.00                                 1.0
# 101                1.00                                 1.0
# 51                 1.00                                 1.0
# 100                1.00                                 1.0
#
#      Visual Recognition\n  Natural Language Processing\n  \
# 158              0.000000                       0.572638
# 109              0.620098                       0.572638
# 131              0.700000                       0.500000
# 55               1.000000                       0.572638
# 94               0.600000                       0.800000
# 29               0.000000                       0.000000
# 101              1.000000                       0.500000
# 51               1.000000                       1.000000
# 100              1.000000                       0.000000
#
#      Reinforcement Learning  Software Production Engineering\n  \
# 158                0.603495                                0.5
# 109                0.603495                                1.0
# 131                0.600000                                0.7
# 55                 0.603495                                1.0
# 94                 1.000000                                1.0
# 29                 0.000000                                1.0
# 101                0.500000                                0.8
# 51                 1.000000                                0.5
# 100                0.000000                                1.0
#
#      Computer Graphics\n  Data Visualization\n  Programming Languages\n  \
# 158             1.000000               1.00000                 0.000000
# 109             0.456217               0.58841                 0.543363
# 131             0.700000               0.70000                 0.800000
# 55              0.000000               0.00000                 0.000000
# 94              0.200000               0.70000                 0.500000
# 29              0.000000               0.00000                 0.000000
# 101             0.300000               0.90000                 0.800000
# 51              0.700000               0.50000                 1.000000
# 100             0.000000               0.00000                 0.000000
#
#      Cloud Computing\n  Digital CMOS VLSI Design   System design with FPGA   \
# 158           0.572587                   0.251538                  0.246316
# 109           0.572587                   0.500000                  1.000000
# 131           0.750000                   0.251538                  0.246316
# 55            0.000000                   0.000000                  0.000000
# 94            0.600000                   0.000000                  0.000000
# 29            0.000000                   0.000000                  0.000000
# 101           0.900000                   0.000000                  0.000000
# 51            0.500000                   0.500000                  0.500000
# 100           0.000000                   0.000000                  0.000000
#
#      ASIC design   VLSI Architecture Design\n  \
# 158      0.214805                    0.234868
# 109      0.700000                    0.500000
# 131      0.214805                    0.234868
# 55       0.000000                    0.000000
# 94       0.000000                    0.000000
# 29       0.000000                    0.000000
# 101      0.000000                    0.000000
# 51       0.400000                    0.200000
# 100      0.000000                    0.000000
#
#      High level synthesis and optimization of Digital Circuits   \
# 158                                           0.168056
# 109                                           0.168056
# 131                                           0.168056
# 55                                            0.000000
# 94                                            0.000000
# 29                                            0.000000
# 101                                           0.000000
# 51                                            0.300000
# 100                                           0.000000
#
#      Digital Sociology   Privacy in the Digital Age  \
# 158            0.318243                    0.452708
# 109            0.318243                    0.452708
# 131            0.318243                    0.452708
# 55             1.000000                    0.000000
# 94             0.000000                    0.500000
# 29             0.000000                    0.000000
# 101            0.000000                    0.600000
# 51             0.400000                    0.500000
# 100            0.000000                    0.000000
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 158                   0.423286                       0.396622
# 109                   0.423286                       0.396622
# 131                   0.423286                       0.900000
# 55                    0.000000                       0.000000
# 94                    0.500000                       0.000000
# 29                    0.000000                       0.000000
# 101                   0.000000                       0.000000
# 51                    1.000000                       0.300000
# 100                   0.000000                       0.000000
#
#      The Web and the Mind
# 158               0.200000
# 109               0.510897
# 131               0.510897
# 55                0.000000
# 94                0.600000
# 29                0.000000
# 101               0.300000
# 51                1.000000
# 100               0.000000

# %% [markdown]
# Trying Prediction on a sample data point from test set

# %%
X_test.to_numpy()[0][:5]
# Out:
# array([1. , 0. , 0. , 0.7, 0.7])

# %%
sorted_ratings = predict(X_test.to_numpy()[0][:5],kmeans_model,matrix_clean)

# %%
s="Top 5 PREDICTED recommended electives are:\n"
for i in range(5):
    s+=df.columns[sorted_ratings[i][1]]+"\n"
print(s)
# Out:
# Top 5 PREDICTED recommended electives are:
# Machine Learning
#
# Mathematics For Machine Learning
#
# Software Production Engineering
#
# Reinforcement Learning
# Data Visualization

# %% [markdown]
# Comparing sample with the actual top 5

# %%
sorted_ratings = []
inferred = y_test.to_numpy()[1]
for idx,element in enumerate(inferred):
    sorted_ratings.append([element,idx+5])
sorted_ratings.sort()
sorted_ratings.reverse()

s="Top 5 ACTUAL recommended electives are:\n"
for i in range(5):
    s+=df.columns[sorted_ratings[i][1]]+"\n"
print(s)
# Out:
# Top 5 ACTUAL recommended electives are:
# System design with FPGA
# Software Production Engineering
#
# Mathematics For Machine Learning
#
# Machine Learning
#
# ASIC design

# %%
X_test.shape
# Out:
# (9, 5)

# %% [markdown]
# ### Functions for whole test series application

# %%
def predict_for_dataset(X_test,kmeans_instance,matrix_clean):
    ''' Runs out inference and return predicted ratings of subjects 
        @input: X_test,kmeans object, clean_matrix after SVD
    '''
    X_test = X_test.to_numpy()
    y_pred = []
    for i in range(X_test.shape[0]):
        datapoint =X_test[i][:5]
        y_pred.append(predict(datapoint,kmeans_instance,matrix_clean))
    return np.array(y_pred)

# %%
y_pred = predict_for_dataset(X_test,kmeans_model,matrix_clean)

# %%
y_pred.shape
# Out:
# (9, 20, 2)

# %%
def accuracy(y_pred,y_test,n=5):
    ''' Finds out % common subject in top 5 rated subjects (predicted and actual) 
        @input: predicted values and test dataset values 
        @output: accuracy value 
    '''
    y_test = y_test.to_numpy()
    sorted_ratings_actual = []
    for i in range(y_test.shape[0]):
        inferred = y_test[i]
        t = []
        for idx,element in enumerate(inferred):
            t.append([element,idx+5])
        t.sort()
        t.reverse()
        sorted_ratings_actual.append(np.array(t))
    sorted_ratings_actual = np.array(sorted_ratings_actual)
    
    total = 0 
    correct = 0 

    
    for i in range(len(sorted_ratings_actual)):
        total+=5
        temp = sorted_ratings_actual[i][:n]
        # if i ==1:
        #     print(temp)
        for j in range(n):
            for k in range(len(temp)):
                if(y_pred[i][j][1]==temp[k][1]):correct+=1

    perecent_correct_for_datapoint = []

    for i in range(len(sorted_ratings_actual)):
        per_correct = 0 
        temp = sorted_ratings_actual[i][:n]
        # if i ==1:
        #     print(temp)
        for j in range(n):
            for k in range(len(temp)):
                if(y_pred[i][j][1]==temp[k][1]):per_correct+=1
        perecent_correct_for_datapoint.append(per_correct/n)
    print("Total Entries received: ", len(sorted_ratings_actual)*n," Total Correct: ",correct)
    return 100*(correct/total),perecent_correct_for_datapoint,sorted_ratings_actual

# %%
overall_val,per_point_val,y_sorted_actual = accuracy(y_pred,y_test)
# Out:
# Total Entries received:  45  Total Correct:  23

# %%
overall_val
# Out:
# 51.11111111111111

# %%
per_point_val
# Out:
# [0.4, 0.6, 0.2, 0.6, 0.8, 0.6, 0.6, 0.2, 0.6]

# %%
def display_subject(sorted_ratings,names,num_recs=5):
    '''
        @input: sorted_ratings list 
        @output: Names of subject corresponding
    '''
    s=""
    for i in range(num_recs):
        s+=names[int(sorted_ratings[i][1])]+"\n"
    return s

# %%
print(display_subject(y_pred[1],df.columns))
# Out:
# Machine Learning
#
# Mathematics For Machine Learning
#
# Software Production Engineering
#
# Reinforcement Learning
# Data Visualization

# %%
print(display_subject(y_sorted_actual[1],df.columns))
# Out:
# System design with FPGA
# Software Production Engineering
#
# Mathematics For Machine Learning
#
# Machine Learning
#
# ASIC design

# %% [markdown]
# #### Accuracy Vs K

# %%
accuracy_list = []
k = range(1,15)
y_ticks = range(0,60)
for i in range(1,15):
    matrix,kmeans_object=cluster_to_matrix(X_train,y_train,i)
    u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=0)
    matrix_clean = u@sigma@V_trans
    matrix_clean = matrix_clean.astype('float')
    y_pred = predict_for_dataset(X_test,kmeans_object,matrix_clean)
    overall_val,per_point_val,y_sorted_actual = accuracy(y_pred,y_test)
    accuracy_list.append(overall_val)
plt.plot(k,accuracy_list)
plt.xlabel('Values of K')
plt.ylabel('Accuracy')
plt.xticks(np.arange(min(k), max(k)+1, 1.0))
plt.yticks(np.arange(min(y_ticks),max(y_ticks)+1,5.0))
plt.show()
# Out:
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  21
# Total Entries received:  45  Total Correct:  21
# Total Entries received:  45  Total Correct:  13
# Total Entries received:  45  Total Correct:  21
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  20
# Total Entries received:  45  Total Correct:  21

# %%
list_df = pd.DataFrame(list(k),columns=["Values of K"])
acc_df = pd.DataFrame(accuracy_list,columns=["Accuracy"])
to_show = pd.concat([list_df,acc_df],axis="columns")

# %%
to_show
# Out:
#     Values of K   Accuracy
# 0             1  51.111111
# 1             2  51.111111
# 2             3  51.111111
# 3             4  51.111111
# 4             5  46.666667
# 5             6  46.666667
# 6             7  28.888889
# 7             8  46.666667
# 8             9  51.111111
# 9            10  51.111111
# 10           11  51.111111
# 11           12  51.111111
# 12           13  44.444444
# 13           14  46.666667

# %% [markdown]
# #### Reduced SVD Analysis

# %%
accuracy_list = []
k = range(0,8)
y_ticks = range(0,60)
for i in range(0,8):
    matrix,kmeans_object=cluster_to_matrix(X_train,y_train,10)
    u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=i)
    matrix_clean = u@sigma@V_trans
    matrix_clean = matrix_clean.astype('float')
    y_pred = predict_for_dataset(X_test,kmeans_object,matrix_clean)
    overall_val,per_point_val,y_sorted_actual = accuracy(y_pred,y_test)
    accuracy_list.append(overall_val)
plt.plot(k,accuracy_list)
plt.xlabel('Singular Values Removed for k=10')
plt.ylabel('Accuracy')
plt.xticks(np.arange(min(k), max(k)+1, 1.0))
plt.yticks(np.arange(min(y_ticks),max(y_ticks)+1,5.0))
plt.show()
# Out:
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23
# Total Entries received:  45  Total Correct:  23

# %%
accuracy_list
# Out:
# [51.11111111111111,
#  51.11111111111111,
#  51.11111111111111,
#  51.11111111111111,
#  51.11111111111111,
#  51.11111111111111,
#  51.11111111111111,
#  51.11111111111111]

# %%
list_df = pd.DataFrame(list(k),columns=["Removed values"])
acc_df = pd.DataFrame(accuracy_list,columns=["Accuracy"])
to_show = pd.concat([list_df,acc_df],axis="columns")
to_show
# Out:
#    Removed values   Accuracy
# 0               0  51.111111
# 1               1  51.111111
# 2               2  51.111111
# 3               3  51.111111
# 4               4  51.111111
# 5               5  51.111111
# 6               6  51.111111
# 7               7  51.111111

# %% [markdown]
# #### Mean Absolute Error Analysis:

# %%
def predict_unsorted(datapoint,kmeans,matrix_clean):
    ''' 
        @input: Takes in a datapoint, kmeans object, and information matrix 
        @output: Returns: rating not-sorted i.e in order of subjects and not ratings 
    '''
    y_pred = kmeans.predictPoint(datapoint)
    inferred_full = matrix_clean[y_pred]
    inferred = inferred_full[5:]
    sorted_ratings = []
    for idx,element in enumerate(inferred):
        sorted_ratings.append(element)
    # sorted_ratings.sort()
    # sorted_ratings.reverse()
    return sorted_ratings

# %%
def predict_for_dataset_unsorted(X_test,kmeans_instance,matrix_clean):
    ''' Runs out inference and return predicted ratings of subjects 
        @input: X_test,kmeans object, clean_matrix after SVD
    '''
    X_test = X_test.to_numpy()
    y_pred = []
    for i in range(X_test.shape[0]):
        datapoint =X_test[i][:5]
        y_pred.append(predict_unsorted(datapoint,kmeans_instance,matrix_clean))
    return np.array(y_pred)

# %% [markdown]
# trial on K=10

# %%
matrix,kmeans_object=cluster_to_matrix(X_train,y_train,10)
u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=i)
matrix_clean = u@sigma@V_trans
matrix_clean = matrix_clean.astype('float')
y_pred = predict_for_dataset_unsorted(X_test,kmeans_object,matrix_clean)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print(mae)
# Out:
# 0.24820232985002538

# %% [markdown]
# MAE VS K

# %%
mae_list = []
k = range(1,15)
# y_ticks = range(0,60)
for i in range(1,15):
    matrix,kmeans_object=cluster_to_matrix(X_train,y_train,i)
    u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=0)
    matrix_clean = u@sigma@V_trans
    matrix_clean = matrix_clean.astype('float')
    y_pred = predict_for_dataset_unsorted(X_test,kmeans_object,matrix_clean)
    from sklearn.metrics import mean_absolute_error
    mae = mean_absolute_error(y_test, y_pred)
    mae_list.append(mae)
plt.plot(k,mae_list)
plt.xlabel('Values of K')
plt.ylabel('Mean Absolute Error')
plt.xticks(np.arange(min(k), max(k)+1, 1.0))
# plt.yticks(np.arange(min(y_ticks),max(y_ticks)+1,5.0))
plt.show()

# %%
list_df = pd.DataFrame(list(k),columns=["Values of K"])
acc_df = pd.DataFrame(mae_list,columns=["Mean Absolute Error"])
to_show = pd.concat([list_df,acc_df],axis="columns")
to_show
# Out:
#     Values of K  Mean Absolute Error
# 0             1             0.249361
# 1             2             0.249429
# 2             3             0.255203
# 3             4             0.257214
# 4             5             0.259738
# 5             6             0.259738
# 6             7             0.484926
# 7             8             0.258805
# 8             9             0.258915
# 9            10             0.257049
# 10           11             0.259118
# 11           12             0.256386
# 12           13             0.266987
# 13           14             0.270604

# %% [markdown]
# MAE vs Reduced SVD

# %%
mae_list = []
k = range(0,8)

for i in range(0,8):
    matrix,kmeans_object=cluster_to_matrix(X_train,y_train,10)
    u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=i)
    matrix_clean = u@sigma@V_trans
    matrix_clean = matrix_clean.astype('float')
    y_pred = predict_for_dataset_unsorted(X_test,kmeans_object,matrix_clean)
    from sklearn.metrics import mean_absolute_error
    mae = mean_absolute_error(y_test, y_pred)
    mae_list.append(mae)

plt.plot(k,mae_list)
plt.xlabel('Singular Values Removed for k=10')
plt.ylabel('Mean Absolute Error')
plt.xticks(np.arange(min(k), max(k)+1, 1.0))
plt.show()

# %%
list_df = pd.DataFrame(list(k),columns=["Singular Values Removed"])
acc_df = pd.DataFrame(mae_list,columns=["Mean Absolute Error"])
to_show = pd.concat([list_df,acc_df],axis="columns")
to_show
# Out:
#    Singular Values Removed  Mean Absolute Error
# 0                        0             0.257049
# 1                        1             0.255749
# 2                        2             0.253799
# 3                        3             0.253154
# 4                        4             0.253531
# 5                        5             0.250622
# 6                        6             0.249031
# 7                        7             0.248202

# %% [markdown]
# #### Cross Validation
# We take values of cluster from 4 to 14 and go on removing 0 to k-1 singular values and try to find the best accuracy (cause the recommendations can be explained better with what you recommend)

# %%
accuracy_list_gs = []
def grid_search(X_train,y_train):
    for i in range(4,15):
        for j in range(0,i):
            try:
                matrix,kmeans_object=cluster_to_matrix(X_train,y_train,i)
                u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=j)
                matrix_clean = u@sigma@V_trans
                matrix_clean = matrix_clean.astype('float')
                y_pred = predict_for_dataset(X_train,kmeans_object,matrix_clean)
                overall_val,per_point_val,y_sorted_actual = accuracy(y_pred,y_train)
                accuracy_list_gs.append([overall_val,('Number of cluster',i),('SV removed',j)])
            except: 
                print(i,j,"index_error")
    accuracy_list_gs.sort(reverse=True)
grid_search(X_train,y_train)
# Out:
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  353
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  353
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  190
# Total Entries received:  765  Total Correct:  196
# Total Entries received:  765  Total Correct:  213
# Total Entries received:  765  Total Correct:  213
# Total Entries received:  765  Total Correct:  140
# Total Entries received:  765  Total Correct:  242
# Total Entries received:  765  Total Correct:  315
# Total Entries received:  765  Total Correct:  353
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  353
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  362
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  372
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  335
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  373
# Total Entries received:  765  Total Correct:  325
# Total Entries received:  765  Total Correct:  325
# Total Entries received:  765  Total Correct:  325
# Total Entries received:  765  Total Correct:  325
# Total Entries received:  765  Total Correct:  325
# Total Entries received:  765  Total Correct:  352
# Total Entries received:  765  Total Correct:  326
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  374
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  325
# Total Entries received:  765  Total Correct:  316
# Total Entries received:  765  Total Correct:  316
# Total Entries received:  765  Total Correct:  316
# Total Entries received:  765  Total Correct:  316
# Total Entries received:  765  Total Correct:  316
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  361
# Total Entries received:  765  Total Correct:  399
# Total Entries received:  765  Total Correct:  316

# %%
accuracy_list_gs

# %% [markdown]
# ### PCA for visualisation
# Keeping k = 10

# %%
# colors = ['red','blue','green','purple','yellow','orange','pink','gray','brown','cyan']

# %%
colors = {0: 'red', 1: 'blue', 2:'green' ,3:'purple',4:'yellow',5:'orange',6:'magenta',7:'gray',8:'brown',9:'cyan'}

# %%
from sklearn.decomposition import PCA
k=Kmeans(K=10,iter=150,p=2,random_state=42)
y_pred=k.predict(np.array(X_train),choice=0)
k.centroids=np.array(k.centroids, dtype='int')
X_train2 = pd.concat([X_train,y_train],axis="columns")
labels = pd.DataFrame(y_pred,columns=["label"],dtype='int')
X_train2.reset_index(inplace=True)
labels.reset_index(inplace=True)
X_train2=pd.concat([X_train2,labels],axis=1)
X_train2
# Out:
#      index  Data Structures and Algorithms  Computer Architecture\n  \
# 0      144                             1.0                      0.7
# 1       19                             0.8                      0.8
# 2       84                             1.0                      0.5
# 3       15                             0.7                      0.9
# 4       66                             1.0                      1.0
# ..     ...                             ...                      ...
# 148     71                             0.5                      0.5
# 149    106                             0.5                      0.8
# 150     14                             0.8                      0.6
# 151     92                             1.0                      1.0
# 152    102                             0.8                      0.2
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                       1.0        0.5            1.0                 1.0
# 1                       0.8        0.5            0.8                 0.9
# 2                       0.0        0.0            1.0                 1.0
# 3                       0.2        0.6            1.0                 1.0
# 4                       1.0        0.0            1.0                 0.0
# ..                      ...        ...            ...                 ...
# 148                     0.0        1.0            0.6                 0.7
# 149                     0.4        0.9            0.7                 1.0
# 150                     0.9        0.9            0.7                 0.8
# 151                     1.0        0.7            1.0                 0.7
# 152                     0.2        0.9            1.0                 0.4
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                   1.0              1.000000
# 1                                   0.9              0.620098
# 2                                   1.0              0.500000
# 3                                   0.8              0.700000
# 4                                   0.0              0.000000
# ..                                  ...                   ...
# 148                                 0.6              0.700000
# 149                                 0.8              0.900000
# 150                                 0.5              0.750000
# 151                                 0.9              0.500000
# 152                                 0.2              0.200000
#
#      Natural Language Processing\n  ...  ASIC design   \
# 0                         0.000000  ...      0.500000
# 1                         0.572638  ...      0.214805
# 2                         0.000000  ...      0.000000
# 3                         0.572638  ...      0.214805
# 4                         0.000000  ...      1.000000
# ..                             ...  ...           ...
# 148                       0.572638  ...      0.214805
# 149                       0.600000  ...      0.000000
# 150                       0.572638  ...      0.214805
# 151                       0.572638  ...      0.214805
# 152                       0.200000  ...      0.000000
#
#      VLSI Architecture Design\n  \
# 0                      0.800000
# 1                      0.234868
# 2                      0.000000
# 3                      0.234868
# 4                      1.000000
# ..                          ...
# 148                    0.234868
# 149                    0.000000
# 150                    0.234868
# 151                    0.234868
# 152                    0.000000
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                             1.000000
# 1                                             0.168056
# 2                                             0.000000
# 3                                             0.168056
# 4                                             0.000000
# ..                                                 ...
# 148                                           0.168056
# 149                                           0.000000
# 150                                           0.168056
# 151                                           0.168056
# 152                                           0.000000
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0              0.500000                    0.000000
# 1              0.318243                    0.300000
# 2              0.318243                    0.452708
# 3              0.318243                    0.600000
# 4              0.318243                    0.452708
# ..                  ...                         ...
# 148            0.318243                    0.452708
# 149            0.000000                    0.500000
# 150            0.318243                    0.400000
# 151            0.500000                    0.452708
# 152            0.500000                    0.000000
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                     0.000000                       0.300000
# 1                     0.423286                       0.396622
# 2                     0.423286                       0.396622
# 3                     0.423286                       0.396622
# 4                     0.423286                       0.396622
# ..                         ...                            ...
# 148                   0.423286                       0.396622
# 149                   0.500000                       0.500000
# 150                   0.423286                       0.396622
# 151                   0.423286                       0.396622
# 152                   0.600000                       0.100000
#
#      The Web and the Mind   index  label
# 0                 0.000000      0      0
# 1                 0.510897      1      0
# 2                 1.000000      2      7
# 3                 0.510897      3      9
# 4                 0.510897      4      5
# ..                     ...    ...    ...
# 148               0.510897    148      8
# 149               0.700000    149      1
# 150               0.510897    150      0
# 151               0.700000    151      0
# 152               0.600000    152      8
#
# [153 rows x 28 columns]

# %%
labels = X_train2['label']
features = X_train2.drop(['label','index'], axis="columns")
pca = PCA(n_components=3)
principal_components = pca.fit_transform(features)

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
for label in labels.unique():
    indices = labels == label
    x = principal_components[indices, 0]
    y = principal_components[indices, 1]
    z = principal_components[indices, 2]
    c = colors[label]

    ax.scatter(x, y, z, c=c, label=label)

sorted_labels = sorted(labels.unique(), key=lambda x: colors[x])

handles = [plt.plot([], [], color=colors[label], marker='o', ls='', label=label)[0] for label in colors.keys()]
ax.legend(handles=handles)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()

# %%
labels = X_train2['label']
features = X_train2.drop(['label','index'], axis="columns")
pca = PCA(n_components=2)
principal_components = pca.fit_transform(features)

fig, ax = plt.subplots()
for label in labels.unique():
    indices = labels == label
    x = principal_components[indices, 0]
    y = principal_components[indices, 1]
    c = colors[label]
    ax.scatter(x, y, c=c, label=label)

sorted_labels = sorted(labels.unique(), key=lambda x: colors[x])

handles = [plt.plot([], [], color=colors[label], marker='o', ls='', label=label)[0] for label in colors.keys()]
ax.legend(handles=handles)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
plt.show()

# %%
cl = np.array(k.clusters)
count_arr = []
for idx,i in enumerate(cl):
    count_arr.append([idx,len(i)])
count_arr
df_count = pd.DataFrame(count_arr,columns=["Cluster Number","Number of points in it"])
df_count
# Out:
# /var/folders/d3/cp13q0jn14z64vh0k61msh680000gn/T/ipykernel_34344/2765835443.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   cl = np.array(k.clusters)
#    Cluster Number  Number of points in it
# 0               0                      52
# 1               1                      10
# 2               2                       5
# 3               3                       6
# 4               4                       5
# 5               5                      14
# 6               6                       0
# 7               7                      13
# 8               8                      21
# 9               9                      27

# %% [markdown]
# #### Top Subjects for Each Cluster

# %%
subjects = ["Data Structures and Algorithms","Computer Architecture","Discrete Mathematics","Economics","Programming-2",
       'Machine Learning', 'Mathematics For Machine Learning',
       'Visual Recognition', 'Natural Language Processing',
       'Reinforcement Learning', 'Software Production Engineering',
       'Computer Graphics', 'Data Visualization',
       'Programming Languages', 'Cloud Computing',
       'Digital CMOS VLSI Design ', 'System design with FPGA ', 'ASIC design ',
       'VLSI Architecture Design',
       'High level synthesis and optimization of Digital Circuits',
       'Digital Sociology ', 'Privacy in the Digital Age',
       'Technology Ethics and AI ', 'Techno-economics of networks ',
       'The Web and the Mind ']

# %%
matrix,kmeans_model=cluster_to_matrix(X_train,y_train,10)
u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=5)
matrix_clean = u@sigma@V_trans
matrix_clean = matrix_clean.astype('float')
vals = []
for i in range(matrix_clean.shape[0]):
    mat = matrix_clean[i][5:]
    sorted_ratings = []
    for idx,element in enumerate(mat):
        sorted_ratings.append([element,idx+5])
    sorted_ratings.sort()
    sorted_ratings.reverse()
    vals.append(sorted_ratings)
for i in range(len(vals)):
    print(i)
    print(display_subject(vals[i],subjects,5) )
# Out:
# 0
# Machine Learning
# Mathematics For Machine Learning
# Software Production Engineering
# Visual Recognition
# Cloud Computing
#
# 1
# Machine Learning
# Mathematics For Machine Learning
# Software Production Engineering
# Natural Language Processing
# Reinforcement Learning
#
# 2
# Machine Learning
# Software Production Engineering
# Cloud Computing
# Programming Languages
# Visual Recognition
#
# 3
# Machine Learning
# Privacy in the Digital Age
# Mathematics For Machine Learning
# Technology Ethics and AI
# The Web and the Mind
#
# 4
# Machine Learning
# Mathematics For Machine Learning
# Reinforcement Learning
# Natural Language Processing
# Visual Recognition
#
# 5
# Software Production Engineering
# Machine Learning
# Mathematics For Machine Learning
# Cloud Computing
# Visual Recognition
#
# 6
# Mathematics For Machine Learning
# Machine Learning
# Natural Language Processing
# Reinforcement Learning
# Software Production Engineering
#
# 7
# Machine Learning
# Mathematics For Machine Learning
# Cloud Computing
# Software Production Engineering
# Data Visualization
#
# 8
# Machine Learning
# Mathematics For Machine Learning
# Software Production Engineering
# Visual Recognition
# Reinforcement Learning

# %% [markdown]
# #### UI for easy testing and prediction

# %%
# !pip install gradio
import gradio as gr
# Out:
# Requirement already satisfied: gradio in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (3.21.0)
# Requirement already satisfied: orjson in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (3.8.7)
# Requirement already satisfied: jinja2 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (3.0.3)
# Requirement already satisfied: typing-extensions in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (4.4.0)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.13.2)
# Requirement already satisfied: pyyaml in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (6.0)
# Requirement already satisfied: python-multipart in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: requests in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.28.1)
# Requirement already satisfied: altair>=4.2.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (4.2.0)
# Requirement already satisfied: matplotlib in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (3.5.3)
# Requirement already satisfied: pydantic in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (1.10.2)
# Requirement already satisfied: ffmpy in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: websockets>=10.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (10.3)
# Requirement already satisfied: pydub in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: httpx in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: pandas in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (1.4.4)
# Requirement already satisfied: numpy in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (1.22.3)
# Requirement already satisfied: aiohttp in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (3.8.3)
# Requirement already satisfied: fsspec in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (2022.10.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: aiofiles in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: fastapi in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.94.1)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: pillow in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (9.2.0)
# Requirement already satisfied: uvicorn in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.21.0)
# Requirement already satisfied: markupsafe in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.1.0)
# Requirement already satisfied: entrypoints in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.2.0->gradio) (4.16.0)
# Requirement already satisfied: toolz in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: packaging>=20.9 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.13.0->gradio) (21.3)
# Requirement already satisfied: filelock in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.13.0->gradio) (3.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.13.0->gradio) (4.64.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from pandas->gradio) (2022.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->gradio) (1.8.1)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from fastapi->gradio) (0.26.1)
# Requirement already satisfied: chardet==3.* in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (3.0.4)
# Requirement already satisfied: hstspreload in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (2022.11.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: certifi in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: httpcore==0.9.* in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (0.9.1)
# Requirement already satisfied: idna==2.* in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (2.10)
# Requirement already satisfied: sniffio in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpx->gradio) (1.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpcore==0.9.*->httpx->gradio) (0.9.0)
# Requirement already satisfied: h2==3.* in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from httpcore==0.9.*->httpx->gradio) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx->gradio) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx->gradio) (3.0.0)
# Requirement already satisfied: cycler>=0.10 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from requests->gradio) (1.26.12)
# Requirement already satisfied: click>=7.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from uvicorn->gradio) (8.0.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.18.1)
# Requirement already satisfied: uc-micro-py in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.1)
# Requirement already satisfied: six>=1.5 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/monjoy/opt/anaconda3/lib/python3.9/site-packages (from starlette<0.27.0,>=0.26.1->fastapi->gradio) (3.5.0)

# %%
text = ["Data Structures and Algorithms","Computer Architecture","Discrete Mathematics","Economics","Programming-2",
       'Machine Learning', 'Mathematics For Machine Learning',
       'Visual Recognition', 'Natural Language Processing',
       'Reinforcement Learning', 'Software Production Engineering',
       'Computer Graphics', 'Data Visualization',
       'Programming Languages', 'Cloud Computing',
       'Digital CMOS VLSI Design ', 'System design with FPGA ', 'ASIC design ',
       'VLSI Architecture Design',
       'High level synthesis and optimization of Digital Circuits',
       'Digital Sociology ', 'Privacy in the Digital Age',
       'Technology Ethics and AI ', 'Techno-economics of networks ',
       'The Web and the Mind ']
def ui(name,num_recs,c1,c2,c3,c4,c5):
    core = np.array([c1,c2,c3,c4,c5])
    matrix,kmeans_model=cluster_to_matrix(X_train,y_train,10)
    print("Allocated Cluster:" ,kmeans_model.predictPoint(core))
    u,s,sigma,V_trans = ReducedSVD(matrix,to_remove=5)
    matrix_clean = u@sigma@V_trans
    matrix_clean = matrix_clean.astype('float')
    subjects=predict(core,kmeans_model,matrix_clean)
    return display_subject(subjects,text,num_recs)
    
    
    
demo = gr.Interface(fn=ui, inputs=[gr.Text(label="Enter your Name (Optional)"),
                                      gr.Slider(int(1),int(20),step=1,label="Number of subjects you want us to recommend?"),
                                      gr.Slider(0,1,label="Data Structures and Algorithms",info="Enter a value between 0 and 1"),
                                      gr.Slider(0,1,label="Computer Architecture",info="Enter a value between 0 and 1"),
                                      gr.Slider(0,1,label="Discrete Mathematics",info="Enter a value between 0 and 1"),
                                      gr.Slider(0,1,label="Economics",info="Enter a value between 0 and 1"),
                                      gr.Slider(0,1,label="Programming-2",info="Enter a value between 0 and 1")], 
                                    outputs=gr.Text(label="Here are your recommendations:(in decreasing order/ preference) "))

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7867
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
