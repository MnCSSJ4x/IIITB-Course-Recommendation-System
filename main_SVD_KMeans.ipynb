# %%
from __future__ import annotations # To prevent Subscript for class "list" will generate runtime exception; enclose type annotation in quotes
import seaborn as sns
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import random
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import scipy
from sklearn.preprocessing import MinMaxScaler
from Kmeans import * 
# %matplotlib inline

# %%
random_state = 42 
df=pd.read_excel('Course Recommendation System.xlsx')
df=df.drop(['ID','Start time','Completion time','Email','Name','Name(not mandatory)\n' ], axis=1)
df['mean'] = df.mean(axis=1,skipna=True,numeric_only=True)
df = df.apply(lambda x : x.fillna(x.mean()),axis=0)
df.drop(axis="columns",labels=["mean"],inplace=True)
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                      0.85       0.90           0.70                0.70
# 1                      0.20       0.80           0.80                0.50
# 2                      1.00       1.00           1.00                1.00
# 3                      0.20       0.75           0.75                0.75
# 4                      0.20       0.00           0.80                0.50
# ..                      ...        ...            ...                 ...
# 157                    0.50       0.70           0.60                0.50
# 158                    0.00       0.70           0.70                0.00
# 159                    0.40       0.90           0.80                0.70
# 160                    0.20       0.40           0.70                0.70
# 161                    0.90       0.40           0.40                0.70
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                  0.80              0.712500
# 1                                  0.10              0.200000
# 2                                  1.00              0.800000
# 3                                  0.75              0.750000
# 4                                  0.60              0.400000
# ..                                  ...                   ...
# 157                                0.30              0.700000
# 158                                0.00              0.000000
# 159                                0.40              0.500000
# 160                                0.80              0.572727
# 161                                0.90              0.622222
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                         0.712500                0.712500  ...
# 1                         0.540000                0.540000  ...
# 2                         0.900000                1.000000  ...
# 3                         0.615385                0.615385  ...
# 4                         0.400000                0.200000  ...
# ..                             ...                     ...  ...
# 157                       0.430000                0.430000  ...
# 158                       0.392308                0.392308  ...
# 159                       0.400000                0.200000  ...
# 160                       0.572727                0.700000  ...
# 161                       0.622222                0.800000  ...
#
#      Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                     0.712500                  0.712500      0.712500
# 1                     0.540000                  0.540000      0.540000
# 2                     0.587500                  0.587500      0.587500
# 3                     0.615385                  0.615385      0.615385
# 4                     0.000000                  0.000000      0.000000
# ..                         ...                       ...           ...
# 157                   0.430000                  0.430000      0.430000
# 158                   0.392308                  0.392308      0.392308
# 159                   0.635294                  0.635294      0.635294
# 160                   0.572727                  0.572727      0.572727
# 161                   0.622222                  0.622222      0.622222
#
#      VLSI Architecture Design\n  \
# 0                      0.712500
# 1                      0.540000
# 2                      0.587500
# 3                      0.615385
# 4                      0.000000
# ..                          ...
# 157                    0.430000
# 158                    0.392308
# 159                    0.635294
# 160                    0.572727
# 161                    0.622222
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                             0.712500
# 1                                             0.540000
# 2                                             0.587500
# 3                                             0.615385
# 4                                             0.000000
# ..                                                 ...
# 157                                           0.430000
# 158                                           0.392308
# 159                                           0.635294
# 160                                           0.572727
# 161                                           0.622222
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0              0.712500                    0.600000
# 1              0.540000                    0.500000
# 2              0.587500                    0.400000
# 3              0.800000                    0.615385
# 4              0.000000                    0.000000
# ..                  ...                         ...
# 157            0.430000                    0.000000
# 158            0.392308                    0.392308
# 159            0.635294                    1.000000
# 160            0.572727                    0.572727
# 161            0.622222                    0.622222
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                     0.712500                       0.712500
# 1                     0.540000                       0.540000
# 2                     0.587500                       0.587500
# 3                     0.615385                       0.800000
# 4                     0.000000                       0.000000
# ..                         ...                            ...
# 157                   0.430000                       0.430000
# 158                   0.392308                       0.392308
# 159                   0.635294                       0.635294
# 160                   0.572727                       0.572727
# 161                   0.622222                       0.622222
#
#      The Web and the Mind
# 0                 0.712500
# 1                 0.540000
# 2                 0.587500
# 3                 0.615385
# 4                 0.000000
# ..                     ...
# 157               0.430000
# 158               0.200000
# 159               1.000000
# 160               0.572727
# 161               0.622222
#
# [162 rows x 25 columns]

# %%
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                              0.30                     0.85
# 1                              0.70                     0.80
# 2                              0.70                     0.00
# 3                              0.65                     0.70
# 4                              0.70                     0.60
# ..                              ...                      ...
# 157                            0.00                     1.00
# 158                            1.00                     0.00
# 159                            0.60                     0.30
# 160                            0.80                     0.60
# 161                            0.40                     0.70
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                      0.85       0.90           0.70                0.70
# 1                      0.20       0.80           0.80                0.50
# 2                      1.00       1.00           1.00                1.00
# 3                      0.20       0.75           0.75                0.75
# 4                      0.20       0.00           0.80                0.50
# ..                      ...        ...            ...                 ...
# 157                    0.50       0.70           0.60                0.50
# 158                    0.00       0.70           0.70                0.00
# 159                    0.40       0.90           0.80                0.70
# 160                    0.20       0.40           0.70                0.70
# 161                    0.90       0.40           0.40                0.70
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                                  0.80              0.712500
# 1                                  0.10              0.200000
# 2                                  1.00              0.800000
# 3                                  0.75              0.750000
# 4                                  0.60              0.400000
# ..                                  ...                   ...
# 157                                0.30              0.700000
# 158                                0.00              0.000000
# 159                                0.40              0.500000
# 160                                0.80              0.572727
# 161                                0.90              0.622222
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                         0.712500                0.712500  ...
# 1                         0.540000                0.540000  ...
# 2                         0.900000                1.000000  ...
# 3                         0.615385                0.615385  ...
# 4                         0.400000                0.200000  ...
# ..                             ...                     ...  ...
# 157                       0.430000                0.430000  ...
# 158                       0.392308                0.392308  ...
# 159                       0.400000                0.200000  ...
# 160                       0.572727                0.700000  ...
# 161                       0.622222                0.800000  ...
#
#      Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                     0.712500                  0.712500      0.712500
# 1                     0.540000                  0.540000      0.540000
# 2                     0.587500                  0.587500      0.587500
# 3                     0.615385                  0.615385      0.615385
# 4                     0.000000                  0.000000      0.000000
# ..                         ...                       ...           ...
# 157                   0.430000                  0.430000      0.430000
# 158                   0.392308                  0.392308      0.392308
# 159                   0.635294                  0.635294      0.635294
# 160                   0.572727                  0.572727      0.572727
# 161                   0.622222                  0.622222      0.622222
#
#      VLSI Architecture Design\n  \
# 0                      0.712500
# 1                      0.540000
# 2                      0.587500
# 3                      0.615385
# 4                      0.000000
# ..                          ...
# 157                    0.430000
# 158                    0.392308
# 159                    0.635294
# 160                    0.572727
# 161                    0.622222
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                             0.712500
# 1                                             0.540000
# 2                                             0.587500
# 3                                             0.615385
# 4                                             0.000000
# ..                                                 ...
# 157                                           0.430000
# 158                                           0.392308
# 159                                           0.635294
# 160                                           0.572727
# 161                                           0.622222
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0              0.712500                    0.600000
# 1              0.540000                    0.500000
# 2              0.587500                    0.400000
# 3              0.800000                    0.615385
# 4              0.000000                    0.000000
# ..                  ...                         ...
# 157            0.430000                    0.000000
# 158            0.392308                    0.392308
# 159            0.635294                    1.000000
# 160            0.572727                    0.572727
# 161            0.622222                    0.622222
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                     0.712500                       0.712500
# 1                     0.540000                       0.540000
# 2                     0.587500                       0.587500
# 3                     0.615385                       0.800000
# 4                     0.000000                       0.000000
# ..                         ...                            ...
# 157                   0.430000                       0.430000
# 158                   0.392308                       0.392308
# 159                   0.635294                       0.635294
# 160                   0.572727                       0.572727
# 161                   0.622222                       0.622222
#
#      The Web and the Mind
# 0                 0.712500
# 1                 0.540000
# 2                 0.587500
# 3                 0.615385
# 4                 0.000000
# ..                     ...
# 157               0.430000
# 158               0.200000
# 159               1.000000
# 160               0.572727
# 161               0.622222
#
# [162 rows x 25 columns]

# %%
from SVD import * 
u,s,sigma,V_trans = ReducedSVD(df.to_numpy(),0,1)

# %%
num_cluster = 6

# %%
df = pd.DataFrame(u@sigma@V_trans,columns=df.columns)

# %%
df
# Out:
#      Data Structures and Algorithms  Computer Architecture\n  \
# 0                          0.300249                 0.850135
# 1                          0.698662                 0.799276
# 2                          0.698457                -0.000835
# 3                          0.650088                 0.700048
# 4                          0.700333                 0.600180
# ..                              ...                      ...
# 157                        0.000679                 1.000367
# 158                        1.000625                 0.000338
# 159                        0.601400                 0.300758
# 160                        0.799208                 0.599571
# 161                        0.399294                 0.699618
#
#      Discrete Mathematics\n  Economics  Programming-2  Machine Learning\n  \
# 0                  0.850113   0.900099       0.699879            0.699975
# 1                  0.199391   0.799466       0.800651            0.500137
# 2                  0.999297   0.999384       1.000751            1.000158
# 3                  0.200040   0.750035       0.749957            0.749991
# 4                  0.200152   0.000133       0.799838            0.499966
# ..                      ...        ...            ...                 ...
# 157                0.500309   0.700271       0.599670            0.499931
# 158                0.000284   0.700249       0.699696           -0.000064
# 159                0.400637   0.900559       0.799319            0.699857
# 160                0.199639   0.399684       0.700385            0.700081
# 161                0.899678   0.399718       0.400344            0.700072
#
#      Mathematics For Machine Learning\n  Visual Recognition\n  \
# 0                              0.799868              0.712559
# 1                              0.100706              0.199685
# 2                              1.000815              0.799637
# 3                              0.749954              0.750021
# 4                              0.599824              0.400078
# ..                                  ...                   ...
# 157                            0.299641              0.700160
# 158                           -0.000330              0.000147
# 159                            0.399261              0.500330
# 160                            0.800418              0.572541
# 161                            0.900373              0.622056
#
#      Natural Language Processing\n  Reinforcement Learning  ...  \
# 0                         0.712043                0.712948  ...
# 1                         0.542454                0.537593  ...
# 2                         0.902830                0.997224  ...
# 3                         0.615224                0.615543  ...
# 4                         0.399390                0.200599  ...
# ..                             ...                     ...  ...
# 157                       0.428755                0.431221  ...
# 158                       0.391162                0.393431  ...
# 159                       0.397432                0.202519  ...
# 160                       0.574180                0.698575  ...
# 161                       0.623518                0.798730  ...
#
#      Digital CMOS VLSI Design   System design with FPGA   ASIC design   \
# 0                     0.714867                  0.711179      0.712369
# 1                     0.527294                  0.547090      0.540703
# 2                     0.572844                  0.595679      0.588310
# 3                     0.616219                  0.614919      0.615338
# 4                     0.003161                 -0.001764     -0.000175
# ..                         ...                       ...           ...
# 157                   0.436449                  0.426401      0.429643
# 158                   0.398241                  0.388997      0.391980
# 159                   0.648591                  0.627874      0.634559
# 160                   0.565203                  0.576926      0.573143
# 161                   0.615515                  0.625965      0.622593
#
#      VLSI Architecture Design\n  \
# 0                      0.709475
# 1                      0.556240
# 2                      0.606233
# 3                      0.614318
# 4                     -0.004040
# ..                          ...
# 157                    0.421758
# 158                    0.384724
# 159                    0.618298
# 160                    0.582345
# 161                    0.630796
#
#      High level synthesis and optimization of Digital Circuits   \
# 0                                             0.714664
# 1                                             0.528384
# 2                                             0.574101
# 3                                             0.616147
# 4                                             0.002890
# ..                                                 ...
# 157                                           0.435896
# 158                                           0.397732
# 159                                           0.647451
# 160                                           0.565848
# 161                                           0.616090
#
#      Digital Sociology   Privacy in the Digital Age  \
# 0              0.712722                    0.600219
# 1              0.538808                    0.498823
# 2              0.586125                    0.398643
# 3              0.800078                    0.615462
# 4              0.000296                    0.000293
# ..                  ...                         ...
# 157            0.430605                    0.000597
# 158            0.392864                    0.392857
# 159            0.636541                    1.001231
# 160            0.572021                    0.572030
# 161            0.621593                    0.621601
#
#      Technology Ethics and AI   Techno-economics of networks   \
# 0                     0.712620                       0.712128
# 1                     0.539357                       0.541999
# 2                     0.586758                       0.589806
# 3                     0.615427                       0.799869
# 4                     0.000160                      -0.000497
# ..                         ...                            ...
# 157                   0.430326                       0.428985
# 158                   0.392608                       0.391374
# 159                   0.635967                       0.633202
# 160                   0.572346                       0.573911
# 161                   0.621883                       0.623278
#
#      The Web and the Mind
# 0                 0.712189
# 1                 0.541672
# 2                 0.589428
# 3                 0.615275
# 4                -0.000416
# ..                     ...
# 157               0.429152
# 158               0.199219
# 159               0.998250
# 160               0.573717
# 161               0.623105
#
# [162 rows x 25 columns]

# %%
def cluster_to_matrix(X_train,y_train,num_cluster):
    k=Kmeans(K=num_cluster,iter=150,p=2,random_state=random_state)
    y_pred=k.predict(np.array(X_train),choice=0)
    k.centroids=np.array(k.centroids, dtype='int')
    X_train2 = pd.concat([X_train,y_train,pd.DataFrame(y_pred,columns=["label"],dtype='int')],axis="columns")
    df_cluster_rep = X_train2.groupby(['label'], as_index=False).mean()
    df_cluster_rep.drop(labels="label",axis="columns",inplace=True)
    matrix = df_cluster_rep.to_numpy()
    return matrix,k

# %%
X = df[[df.columns[0],df.columns[1],df.columns[2],df.columns[3],df.columns[4]]]
y = df.drop(labels=["Data Structures and Algorithms","Computer Architecture\n","Discrete Mathematics\n","Economics","Programming-2"],axis="columns")

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.05, shuffle=True,random_state=random_state)

# %%
matrix,kmeans_model = cluster_to_matrix(X_train,y_train,num_cluster)

# %%
matrix.shape
# Out:
# (6, 25)

# %%
def predict(datapoint,kmeans,matrix_clean):
    ''' 
        @input: Takes in a datapoint, kmeans object, and information matrix 
        @output: Returns: rating sorted with index for column name mapping
    '''
    y_pred = kmeans.predictPoint(datapoint)
    inferred_full = matrix_clean[y_pred]
    inferred = inferred_full[5:]
    sorted_ratings = []
    for idx,element in enumerate(inferred):
        sorted_ratings.append([element,idx+5])
    sorted_ratings.sort()
    sorted_ratings.reverse()
    return sorted_ratings

# %%
X_test.to_numpy()[0][:5]
sorted_ratings = predict(X_test.to_numpy()[0][:5],kmeans_model,matrix)
s="Top 5 PREDICTED recommended electives are:\n"
for i in range(5):
    s+=df.columns[sorted_ratings[i][1]]+"\n"
print(s)
# Out:
# Top 5 PREDICTED recommended electives are:
# Machine Learning
#
# Mathematics For Machine Learning
#
# Reinforcement Learning
# Data Visualization
#
# Visual Recognition

# %%
inferred = y_test.to_numpy()[0]
for idx,element in enumerate(inferred):
    sorted_ratings.append([element,idx+5])
sorted_ratings.sort()
sorted_ratings.reverse()
s="Top 5 ACTUAL recommended electives are:\n"
for i in range(5):
    s+=df.columns[sorted_ratings[i][1]]+"\n"
print(s)
# Out:
# Top 5 ACTUAL recommended electives are:
# Computer Graphics
#
# Data Visualization
#
# Machine Learning
#
# Mathematics For Machine Learning
#
# Reinforcement Learning

# %%
def predict_for_dataset(X_test,kmeans_instance,matrix_clean):
    ''' Runs out inference and return predicted ratings of subjects 
        @input: X_test,kmeans object, clean_matrix after SVD
    '''
    X_test = X_test.to_numpy()
    y_pred = []
    for i in range(X_test.shape[0]):
        datapoint =X_test[i][:5]
        y_pred.append(predict(datapoint,kmeans_instance,matrix_clean))
    return np.array(y_pred)

# %%
y_pred = predict_for_dataset(X_test,kmeans_model,matrix) 
y_pred.shape
# Out:
# (9, 20, 2)

# %%
def accuracy(y_pred,y_test):
    ''' Finds out % common subject in top 5 rated subjects (predicted and actual) 
        @input: predicted values and test dataset values 
        @output: accuracy value 
    '''
    y_test = y_test.to_numpy()
    sorted_ratings_actual = []
    for i in range(y_test.shape[0]):
        inferred = y_test[i]
        t = []
        for idx,element in enumerate(inferred):
            t.append([element,idx+5])
        t.sort()
        t.reverse()
        sorted_ratings_actual.append(np.array(t))
    sorted_ratings_actual = np.array(sorted_ratings_actual)
    
    total = 0 
    correct = 0 

    
    for i in range(len(sorted_ratings_actual)):
        total+=5
        temp = sorted_ratings_actual[i][:5]
        # if i ==1:
        #     print(temp)
        for j in range(5):
            for k in range(len(temp)):
                if(y_pred[i][j][1]==temp[k][1]):correct+=1

    perecent_correct_for_datapoint = []

    for i in range(len(sorted_ratings_actual)):
        per_correct = 0 
        temp = sorted_ratings_actual[i][:5]
        # if i ==1:
        #     print(temp)
        for j in range(5):
            for k in range(len(temp)):
                if(y_pred[i][j][1]==temp[k][1]):per_correct+=1
        perecent_correct_for_datapoint.append(per_correct/5)
    # print("Total Entries received: ", len(sorted_ratings_actual)*5," Total Correct: ",correct)
    return 100*(correct/total),perecent_correct_for_datapoint,sorted_ratings_actual

# %%
overall_val,per_point_val,y_sorted_actual = accuracy(y_pred,y_test)

# %%
overall_val
# Out:
# 46.666666666666664

# %%
per_point_val
# Out:
# [0.2, 0.4, 0.0, 0.6, 0.6, 0.4, 0.8, 0.6, 0.6]

# %% [markdown]
# #### Grid Search

# %%
from SVD import * 
from sklearn.model_selection import train_test_split
accuracy_list_gs = []
def grid_search(df):
    for i in range(4,9):
        for j in range(0,i):
            # print(i,j)
            u,s,sigma,V_trans = ReducedSVD(df.to_numpy(),0,j)
            df = pd.DataFrame(u@sigma@V_trans,columns=df.columns)
            X = df[[df.columns[0],df.columns[1],df.columns[2],df.columns[3],df.columns[4]]]
            y = df.drop(labels=["Data Structures and Algorithms","Computer Architecture\n","Discrete Mathematics\n","Economics","Programming-2"],axis="columns")
            X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.05, shuffle=True,random_state=random_state)
            matrix,kmeans_model = cluster_to_matrix(X_train,y_train,i)
            if(matrix.shape[0]<i):
                break
            y_pred = predict_for_dataset(X_train,kmeans_model,matrix)
            overall_val,per_point_val,y_sorted_actual = accuracy(y_pred,y_train)
            accuracy_list_gs.append([overall_val,('Number of cluster',i),('SV removed',j)])
    accuracy_list_gs.sort(reverse=True)
grid_search(df)
# Out:
# /Users/monjoy/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/SVD.py:155: RuntimeWarning: invalid value encountered in sqrt
#   s = np.sqrt(eigvals)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/d3/cp13q0jn14z64vh0k61msh680000gn/T/ipykernel_14158/182695121.py in <module>
#      18             accuracy_list_gs.append([overall_val,('Number of cluster',i),('SV removed',j)])
#      19     accuracy_list_gs.sort(reverse=True)
# ---> 20 grid_search(df)
#
# /var/folders/d3/cp13q0jn14z64vh0k61msh680000gn/T/ipykernel_14158/182695121.py in grid_search(df)
#      11             y = df.drop(labels=["Data Structures and Algorithms","Computer Architecture\n","Discrete Mathematics\n","Economics","Programming-2"],axis="columns")
#      12             X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.05, shuffle=True,random_state=random_state)
# ---> 13             matrix,kmeans_model = cluster_to_matrix(X_train,y_train,i)
#      14             if(matrix.shape[0]<i):
#      15                 break
#
# /var/folders/d3/cp13q0jn14z64vh0k61msh680000gn/T/ipykernel_14158/1129417720.py in cluster_to_matrix(X_train, y_train, num_cluster)
#       1 def cluster_to_matrix(X_train,y_train,num_cluster):
#       2     k=Kmeans(K=num_cluster,iter=150,p=2,random_state=random_state)
# ----> 3     y_pred=k.predict(np.array(X_train),choice=0)
#       4     k.centroids=np.array(k.centroids, dtype='int')
#       5     X_train2 = pd.concat([X_train,y_train,pd.DataFrame(y_pred,columns=["label"],dtype='int')],axis="columns")
#
# ~/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/Kmeans.py in predict(self, X, choice)
#      99         for _ in range(self.iter):
#     100             # update clusters
# --> 101             self.clusters = self._create_clusters(self.centroids)
#     102             # update centroids
#     103             centroids_old = self.centroids  # for convergence test
#
# ~/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/Kmeans.py in _create_clusters(self, centroids)
#     120             # find the closest centroid to classify, then put it in the specific cluster
#     121             # here cluster is an list of list
# --> 122             centroid_idx = self._closest_centroid(sample, centroids)
#     123             clusters[centroid_idx].append(idx)
#     124         return clusters
#
# ~/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/Kmeans.py in _closest_centroid(self, sample, centroids)
#     129     def _closest_centroid(self, sample, centroids):
#     130         # distance metric
# --> 131         distances = [minkowski_distance(sample, point, self.p)
#     132                      for point in centroids]
#     133         # argmin for required parameters
#
# ~/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/Kmeans.py in <listcomp>(.0)
#     129     def _closest_centroid(self, sample, centroids):
#     130         # distance metric
# --> 131         distances = [minkowski_distance(sample, point, self.p)
#     132                      for point in centroids]
#     133         # argmin for required parameters
#
# ~/Library/CloudStorage/OneDrive-iiit-b/Semester 6/Reccomendation Systems/Project/Course-Recommendation-System/Kmeans.py in minkowski_distance(x1, x2, p)
#      23 def minkowski_distance(x1, x2, p):
#      24     from scipy.spatial import distance
# ---> 25     return distance.minkowski(x1, x2, p)
#      26
#      27
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/spatial/distance.py in minkowski(u, v, p, w)
#     499             root_w = np.power(w, 1/p)
#     500         u_v = root_w * u_v
# --> 501     dist = norm(u_v, ord=p)
#     502     return dist
#     503
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
#     143     # Differs from numpy only in non-finite handling and the use of blas.
#     144     if check_finite:
# --> 145         a = np.asarray_chkfinite(a)
#     146     else:
#     147         a = np.asarray(a)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     601     a = asarray(a, dtype=dtype, order=order)
#     602     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603         raise ValueError(
#     604             "array must not contain infs or NaNs")
#     605     return a
#
# ValueError: array must not contain infs or NaNs

# %%
accuracy_list_gs

# %%
k = 6
to_remove = 1
